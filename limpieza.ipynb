# %%
# Importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Evaluar linealidad de las relaciones entre las variables
# y la distribución de las variables
# ------------------------------------------------------------------------------
import scipy.stats as stats

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames
#pd.set_option('display.max_rows', None)
# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# %%
spotify=pd.read_csv("spotify-2023.csv")

# %%
spotify
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
def data_exploring(csv):
    forma = csv.shape
    print(f"La forma es {forma}")
    print("_______________")
    columnas = csv.columns
    print(f"Las columnas son {columnas}")
    print("_______________")
    nulos = csv.isna().sum().reset_index()
    print(f"Los nulos son:")
    display(nulos)
    print("_______________")
    duplicados = csv.duplicated().sum()
    print(f"Hay {duplicados} duplicados")
    print("_______________")
    tipo_dato = csv.dtypes.reset_index()
    print(f"Los datos son de tipo:")
    display(tipo_dato)

# %%
data_exploring(spotify)
# Out:
# La forma es (953, 24)
# _______________
# Las columnas son Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')
# _______________
# Los nulos son:
#                    index   0
# 0             track_name   0
# 1         artist(s)_name   0
# 2           artist_count   0
# 3          released_year   0
# 4         released_month   0
# 5           released_day   0
# 6   in_spotify_playlists   0
# 7      in_spotify_charts   0
# 8                streams   0
# 9     in_apple_playlists   0
# 10       in_apple_charts   0
# 11   in_deezer_playlists   0
# ...

# %%
def limpiar_valores(spotify):
 
    # Reemplazar '_' con un espacio en blanco y eliminar '%'
    spotify.columns = spotify.columns.str.replace('_', '').str.replace('%', '')

# %%
limpiar_valores(spotify)

# %%
spotify.columns
# Out:
# Index(['trackname', 'artist(s)name', 'artistcount', 'releasedyear',
#        'releasedmonth', 'releasedday', 'inspotifyplaylists', 'inspotifycharts',
#        'streams', 'inappleplaylists', 'inapplecharts', 'indeezerplaylists',
#        'indeezercharts', 'inshazamcharts', 'bpm', 'key', 'mode',
#        'danceability', 'valence', 'energy', 'acousticness', 'instrumentalness',
#        'liveness', 'speechiness'],
#       dtype='object')

# %%
spotify.drop(columns=["key","mode"], inplace=True)

# %%
spotify.tail()
# Out:
#                      trackname       artist(s)name  artistcount  releasedyear  \
# 948               My Mind & Me        Selena Gomez            1          2022
# 949  Bigger Than The Whole Sky        Taylor Swift            1          2022
# 950       A Veces (feat. Feid)  Feid, Paulo Londra            2          2022
# 951              En La De Ella  Feid, Sech, Jhayco            3          2022
# 952                      Alone           Burna Boy            1          2022
#
#      releasedmonth  releasedday  inspotifyplaylists  inspotifycharts  \
# 948             11            3                 953                0
# 949             10           21                1180                0
# 950             11            3                 573                0
# 951             10           20                1320                0
# 952             11            4                 782                2
#
#        streams  inappleplaylists  inapplecharts indeezerplaylists  \
# ...

# %%
spotify.columns
# Out:
# Index(['trackname', 'artist(s)name', 'artistcount', 'releasedyear',
#        'releasedmonth', 'releasedday', 'inspotifyplaylists', 'inspotifycharts',
#        'streams', 'inappleplaylists', 'inapplecharts', 'indeezerplaylists',
#        'indeezercharts', 'inshazamcharts', 'bpm', 'danceability', 'valence',
#        'energy', 'acousticness', 'instrumentalness', 'liveness',
#        'speechiness'],
#       dtype='object')

# %%
spotify["artist(s)name"].unique()
# Out:
# array(['Latto, Jung Kook', 'Myke Towers', 'Olivia Rodrigo',
#        'Taylor Swift', 'Bad Bunny', 'Dave, Central Cee',
#        'Eslabon Armado, Peso Pluma', 'Quevedo', 'Gunna',
#        'Peso Pluma, Yng Lvcas', 'Bad Bunny, Grupo Frontera', 'NewJeans',
#        'Miley Cyrus', 'David Kushner', 'Harry Styles', 'SZA',
#        'Fifty Fifty', 'Billie Eilish', 'Feid, Young Miko', 'Jimin',
#        'Gabito Ballesteros, Junior H, Peso Pluma', 'Arctic Monkeys',
#        'Bizarrap, Peso Pluma', 'The Weeknd, Madonna, Playboi Carti',
#        'Fuerza Regida', 'R��ma, Selena G', 'Tainy, Bad Bunny',
#        'Morgan Wallen', 'Dua Lipa', 'Troye Sivan',
#        'Peso Pluma, Grupo Frontera',
#        'The Weeknd, 21 Savage, Metro Boomin', 'Karol G, Shakira',
#        'Big One, Duki, Lit Killah, Maria Becerra, FMK, Rusherking, Emilia, Tiago pzk',
#        'Yahritza Y Su Esencia, Grupo Frontera', 'Junior H, Peso Pluma',
#        'Post Malone, Swae Lee', 'Bebe Rexha, David Guetta',
# ...

# %%
list(spotify["artist(s)name"])
# Out:
# ['Latto, Jung Kook',
#  'Myke Towers',
#  'Olivia Rodrigo',
#  'Taylor Swift',
#  'Bad Bunny',
#  'Dave, Central Cee',
#  'Eslabon Armado, Peso Pluma',
#  'Quevedo',
#  'Gunna',
#  'Peso Pluma, Yng Lvcas',
#  'Bad Bunny, Grupo Frontera',
#  'NewJeans',
#  'Miley Cyrus',
#  'David Kushner',
#  'Harry Styles',
#  'SZA',
#  'Fifty Fifty',
#  'Billie Eilish',
#  'Feid, Young Miko',
#  'Jimin',
#  'Gabito Ballesteros, Junior H, Peso Pluma',
#  'Taylor Swift',
#  'Arctic Monkeys',
#  'Bizarrap, Peso Pluma',
#  'The Weeknd, Madonna, Playboi Carti',
#  'Fuerza Regida',
#  'R��ma, Selena G',
#  'Tainy, Bad Bunny',
#  'Morgan Wallen',
#  'Dua Lipa',
#  'Troye Sivan',
#  'Peso Pluma, Grupo Frontera',
#  'The Weeknd, 21 Savage, Metro Boomin',
#  'Taylor Swift',
#  'Karol G, Shakira',
#  'Big One, Duki, Lit Killah, Maria Becerra, FMK, Rusherking, Emilia, Tiago pzk',
#  'Yahritza Y Su Esencia, Grupo Frontera',
#  'Taylor Swift',
#  'Taylor Swift',
#  'Fuerza Regida',
#  'Junior H, Peso Pluma',
# ...

# %%
def limpiar(dataframe):
    for col in dataframe.columns:
        # Verificar si el nombre de la columna no es 'track_name' ni 'artist(s)_name'
        if col not in ['trackname', 'artist(s)name']:
            # Verificar si el tipo de datos de la columna es una cadena
            if dataframe[col].dtype == 'object':
                # Reemplazar la coma (,) con un punto (.)
                dataframe[col] = dataframe[col].str.replace(",", "")
                # Intentar convertir los valores a números enteros si es posible
                try:
                    dataframe[col] = dataframe[col].astype(int)
                except ValueError:
                    pass  # Ignorar si no se puede convertir a int

# %%
data_dict = [
    {'artista': 'Latto Jung Kook', 'pais': 'Estados Unidos'},
    {'artista': 'Burna Boy', 'pais': 'Nigeria'},
    {'artista': 'Myke Towers', 'pais': 'Puerto Rico'},
    {'artista': 'Olivia Rodrigo', 'pais': 'Estados Unidos'},
    {'artista': 'Taylor Swift', 'pais': 'Estados Unidos'},
    {'artista': 'Bad Bunny', 'pais': 'Puerto Rico'},
    {'artista': 'Dave Central Cee', 'pais': 'Reino Unido'},
    {'artista': 'Eslabon Armado Peso Pluma', 'pais': 'Estados Unidos'},
    {'artista': 'Quevedo', 'pais': 'España'},
    {'artista': 'Gunna', 'pais': 'Estados Unidos'},
    {'artista': 'Peso Pluma Yng Lvcas', 'pais': 'Mexico'},
    {'artista': 'Bad Bunny Grupo Frontera', 'pais': 'Puerto Rico'},
    {'artista': 'NewJeans', 'pais': "Corea del Sur"},
    {'artista': 'Miley Cyrus', 'pais': 'Estados Unidos'},
    {'artista': 'David Kushner', 'pais': 'Estados Unidos'},
    {'artista': 'Harry Styles', 'pais': 'Reino Unido'},
    {'artista': 'SZA', 'pais': 'Estados Unidos'},
    {'artista': 'Fifty Fifty', 'pais': "Corea del Sur"},
    {'artista': 'Billie Eilish', 'pais': 'Estados Unidos'},
    {'artista': 'Feid Young Miko', 'pais': 'Colombia'},
    {'artista': 'Jimin', 'pais': 'Corea del Sur'},
    {'artista': 'Gabito Ballesteros Junior H Peso Pluma', 'pais': 'México'},
    {'artista': 'Arctic Monkeys', 'pais': 'Reino Unido'},
    {'artista': 'Bizarrap Peso Pluma', 'pais': 'Argentina'},
    {'artista': 'The Weeknd Madonna Playboi Carti', 'pais': 'Canadá'},
    {'artista': 'Fuerza Regida', 'pais': 'México'},
    {'artista': 'R��ma Selena G', 'pais': "Nigeria"},
    {'artista': 'Tainy Bad Bunny', 'pais': 'Puerto Rico'},
    {'artista': 'Morgan Wallen', 'pais': 'Estados Unidos'},
    {'artista': 'Dua Lipa', 'pais': 'Reino Unido'},
    {'artista': 'Troye Sivan', 'pais': 'Australia'},
    {'artista': 'Peso Pluma Grupo Frontera', 'pais': "México"},
    {'artista': 'The Weeknd 21 Savage Metro Boomin', 'pais': 'Canadá'},
    {'artista': 'Karol G Shakira', 'pais': 'Colombia'},
    {'artista': 'Big One Duki Lit Killah Maria Becerra FMK Rusherking Emilia Tiago pzk', 'pais': 'Argentina'},
    {'artista': 'Yahritza Y Su Esencia Grupo Frontera', 'pais': "México"},
    {'artista': 'Junior H Peso Pluma', 'pais': 'Estados Unidos'},
    {'artista': 'Post Malone Swae Lee', 'pais': 'Estados Unidos'},
    {'artista': 'Bebe Rexha David Guetta', 'pais': 'Estados Unidos'},
    {'artista': 'Tyler The Creator Kali Uchis', 'pais': 'Estados Unidos'},
    {'artista': 'Nicki Minaj Aqua Ice Spice', 'pais': 'Trinidad y Tobago'},
    {'artista': 'OneRepublic', 'pais': 'Estados Unidos'},
    {'artista': 'The Weeknd', 'pais': 'Canadá'},
    {'artista': 'The Weeknd Daft Punk', 'pais': 'Canadá'},
    {'artista': 'Ariana Grande The Weeknd', 'pais': 'Estados Unidos'},
    {'artista': 'Feid Myke Towers Sky Rompiendo', 'pais': 'Colombia'},
    {'artista': 'David Guetta Anne-Marie Coi Leray', 'pais': 'Francia'},
    {'artista': 'Karol G', 'pais': 'Colombia'},
    {'artista': 'Peggy Gou', 'pais': 'Corea del Sur'},
    {'artista': 'Tom Odell', 'pais': 'Reino Unido'},
    {'artista': 'Kali Uchis', 'pais': 'Estados Unidos'},
    {'artista': 'Manuel Turizo', 'pais': 'Colombia'},
    {'artista': 'dennis MC Kevin o Chris', 'pais': "Guatemala"},
    {'artista': 'PinkPantheress Ice Spice', 'pais': 'Reino Unido'},
    {'artista': 'Charlie Puth BTS Jung Kook', 'pais': 'Estados Unidos'},
    {'artista': 'Rauw Alejandro ROSAL�', 'pais': 'Puerto Rico'},
    {'artista': 'Ozuna Feid', 'pais': 'Puerto Rico'},
    {'artista': 'Chris Molitor', 'pais': 'Estados Unidos'},
    {'artista': 'Libianca', 'pais': 'Estados Unidos'},
    {'artista': 'Post Malone', 'pais': 'Estados Unidos'},
    {'artista': 'Rauw Alejandro Bizarrap', 'pais': 'Puerto Rico'},
    {'artista': 'Glass Animals', 'pais': 'Reino Unido'},
    {'artista': 'JVKE', 'pais': 'Estados Unidos'},
    {'artista': 'The Neighbourhood', 'pais': 'Estados Unidos'},
    {'artista': 'Bizarrap Quevedo', 'pais': 'Argentina'},
    {'artista': 'Coldplay', 'pais': 'Reino Unido'},
    {'artista': 'd4vd', 'pais': 'Estados Unidos'},
    {'artista': 'Sam Smith Kim Petras', 'pais': 'Reino Unido'},
    {'artista': 'Yandel Feid', 'pais': 'Puerto Rico'},
    {'artista': 'Maria Becerra', 'pais': 'Argentina'},
    {'artista': 'Vance Joy', 'pais': 'Australia'},
    {'artista': 'Em Beihold Stephen Sanchez', 'pais': "Irán"},
    {'artista': 'Mc Livinho DJ Matt D', 'pais': 'Brasil'},
    {'artista': 'Justin Bieber The Kid Laroi', 'pais': 'Canadá'},
    {'artista': 'Marshmello Manuel Turizo', 'pais': 'Estados Unidos'},
    {'artista': 'Lewis Capaldi', 'pais': 'Reino Unido'},
    {'artista': 'Chencho Corleone Bad Bunny', 'pais': 'Puerto Rico'},
    {'artista': 'Jain', 'pais': 'Francia'},
    {'artista': 'Ayparia unxbected', 'pais': 'Estados Unidos'},
    {'artista': 'Latto', 'pais': 'Estados Unidos'}, 
    {'artista': 'Jung Kook', 'pais': 'Corea del Sur'}, 
    {'artista': 'Dave', 'pais': 'Reino Unido'}, 
    {'artista': 'Central Cee', 'pais': 'Reino Unido'}, 
    {'artista': 'Eslabon Armado', 'pais': 'México'}, 
    {'artista': 'Peso Pluma', 'pais': 'México'}, 
    {'artista': 'Yng Lvcas', 'pais': 'México'}, 
    {'artista': 'Feid', 'pais': 'Colombia'}, 
    {'artista': 'Young Miko', 'pais': 'Argentina'},
    {'artista': 'Gabito Ballesteros', 'pais': 'México'}, 
    {'artista': 'Junior H', 'pais': 'México'}, 
    {'artista': 'Bizarrap', 'pais': 'Argentina'}, 
    {'artista': 'R��ma', 'pais': 'Nigeria'}, 
    {'artista': 'Selena G', 'pais': 'Estados Unidos'}, 
    {'artista': 'Tainy', 'pais': 'Puerto Rico'}, 
    {'artista': 'Bad Bunny', 'pais': 'Puerto Rico'}, 
    {'artista': 'Grupo Frontera', 'pais': 'México'}, 
    {'artista': 'Big One', 'pais': 'Argentina'}, 
    {'artista': 'Duki', 'pais': 'Argentina'}, 
    {'artista': 'Lit Killah', 'pais': 'Argentina'}, 
    {'artista': 'Maria Becerra', 'pais': 'Argentina'}, 
    {'artista': 'FMK', 'pais': 'Argentina'}, 
    {'artista': 'Rusherking', 'pais': 'Argentina'}, 
    {'artista': 'Emilia', 'pais': 'Argentina'}, 
    {'artista': 'Tiago pzk', 'pais': 'Argentina'}, 
    {'artista': 'Yahritza Y Su Esencia', 'pais': 'México'}, 
    {'artista': 'Bebe Rexha', 'pais': 'Estados Unidos'}, 
    {'artista': 'David Guetta', 'pais': 'Francia'}, 
    {'artista': 'Tyler', 'pais': 'Estados Unidos'}, 
    {'artista': 'The Creator', 'pais': 'Estados Unidos'}, 
    {'artista': 'Kali Uchis', 'pais': 'Estados Unidos'}, 
    {'artista': 'Nicki Minaj', 'pais': 'Trinidad y Tobago'}, 
    {'artista': 'Aqua', 'pais': 'Dinamarca'}, 
    {'artista': 'Ice Spice', 'pais': 'Estados Unidos'}, 
    {'artista': 'Ariana Grande', 'pais': 'Estados Unidos'}, 
    {'artista': 'The Weeknd', 'pais': 'Canadá'}, 
    {'artista': 'Myke Towers', 'pais': 'Puerto Rico'}, 
    {'artista': 'Sky Rompiendo', 'pais': 'Colombia'}, 
    {'artista': 'Anne-Marie', 'pais': 'Reino Unido'}, 
    {'artista': 'Coi Leray', 'pais': 'Estados Unidos'}, 
    {'artista': 'dennis', 'pais': 'Brasil'}, 
    {'artista': 'MC Kevin o Chris', 'pais': 'Brasil'}, 
    {'artista': 'PinkPantheress', 'pais': 'Reino Unido'}, 
    {'artista': 'Charlie Puth', 'pais': 'Estados Unidos'}, 
    {'artista': 'BTS', 'pais': 'Corea del Sur'}, 
    {'artista': 'Rauw Alejandro', 'pais': 'Puerto Rico'}, 
    {'artista': 'ROSAL�', 'pais': 'España'}, 
    {'artista': 'Ozuna', 'pais': 'Puerto Rico'}, 
    {'artista': 'Quevedo', 'pais': 'España'}, 
    {'artista': 'Sam Smith', 'pais': 'Reino Unido'}, 
    {'artista': 'Kim Petras', 'pais': 'Alemania'}, 
    {'artista': 'Yandel', 'pais': 'Puerto Rico'}, 
    {'artista': 'Stephen Sanchez', 'pais': 'Estados Unidos'}, 
    {'artista': 'Mc Livinho', 'pais': 'Brasil'}, 
    {'artista': 'DJ Matt D', 'pais': 'Rusia'}, 
    {'artista': 'Justin Bieber', 'pais': 'Canadá'}, 
    {'artista': 'The Kid Laroi', 'pais': 'Australia'}, 
    {'artista': 'Marshmello', 'pais': 'Estados Unidos'}, 
    {'artista': 'Manuel Turizo', 'pais': 'Colombia'}, 
    {'artista': 'Chencho Corleone', 'pais': 'Puerto Rico'}, 
    {'artista': 'Ayparia', 'pais': 'Brasil'}, 
    {'artista': 'unxbected', 'pais': 'Brasil'}, 
    {'artista': 'Luke Combs', 'pais': 'Estados Unidos'}, 
    {'artista': 'Doechii', 'pais': 'Estados Unidos'}, 
    {'artista': 'J. Cole', 'pais': 'Estados Unidos'}, 
    {'artista': 'Lil Durk', 'pais': 'Estados Unidos'}, 
    {'artista': 'Lana Del Rey', 'pais': 'Estados Unidos'}, 
    {'artista': 'Future', 'pais': 'Estados Unidos'}, 
    {'artista': 'Metro Boomin', 'pais': 'Estados Unidos'}, 
    {'artista': 'Don Toliver', 'pais': 'Estados Unidos'}, 
    {'artista': 'Eminem', 'pais': 'Estados Unidos'}, 
    {'artista': 'Carin Leon', 'pais': 'México'}, 
    {'artista': 'Ruth B.', 'pais': 'Canadá'}, 
    {'artista': 'Imagine Dragons', 'pais': 'Estados Unidos'}, 
    {'artista': 'Adele', 'pais': 'Reino Unido'}, 
    {'artista': 'Kendrick Lamar', 'pais': 'Estados Unidos'}, 
    {'artista': 'Jay Rock', 'pais': 'Estados Unidos'}, 
    {'artista': 'Anggi Marito', 'pais': 'Indonesia'}, 
    {'artista': 'Jasiel Nu��ez', 'pais': 'México'}, 
    {'artista': 'Tears For Fears', 'pais': 'Reino Unido'}, 
    {'artista': 'Loreen', 'pais': 'Suecia'}, 
    {'artista': 'Taiu', 'pais': 'Taiwan'}, 
    {'artista': 'Milo j', 'pais': 'Argentina'}, 
    {'artista': 'Sebastian Yatra', 'pais': 'Colombia'}, 
    {'artista': 'Manuel Turizo', 'pais': 'Colombia'}, 
    {'artista': 'Be��', 'pais': 'Desconocido'}, 
    {'artista': 'Calvin Harris', 'pais': 'Reino Unido'}, 
    {'artista': 'Ellie Goulding', 'pais': 'Reino Unido'}, 
    {'artista': 'Sabrina Carpenter', 'pais': 'Estados Unidos'}, 
    {'artista': 'Ray Dalton', 'pais': 'Estados Unidos'}, 
    {'artista': 'Ryan Lewis', 'pais': 'Estados Unidos'}, 
    {'artista': 'Macklemore', 'pais': 'Estados Unidos'}, 
    {'artista': 'Shakira', 'pais': 'Colombia'}, 
    {'artista': 'Swae Lee', 'pais': 'Estados Unidos'}, 
    {'artista': 'A Boogie Wit da Hoodie', 'pais': 'Estados Unidos'}, 
    {'artista': 'NAV', 'pais': 'Canadá'}, 
    {'artista': 'Sachin-Jigar', 'pais': 'India'}, 
    {'artista': 'Shadab Faridi', 'pais': 'India'}, 
    {'artista': 'Altamash Faridi', 'pais': 'India'}, 
    {'artista': 'Amitabh Bhattacharya', 'pais': 'India'}, 
    {'artista': 'Varun Jain', 'pais': 'India'}, 
    {'artista': 'Ed Sheeran', 'pais': 'Reino Unido'}, 
    {'artista': 'Veigh', 'pais': 'Brasil'}, 
    {'artista': 'Bvga Beatz', 'pais': 'Brasil'}, 
    {'artista': 'Supernova Ent', 'pais': 'Chile'}, 
    {'artista': 'Prod Malax', 'pais': 'Desconocido'}, 
    {'artista': 'Mc Pedrinho', 'pais': 'Brasil'}, 
    {'artista': 'DJ 900', 'pais': 'Desconocido'}, 
    {'artista': 'Sog', 'pais': 'Colombia'}, 
    {'artista': 'Ryan Castro', 'pais': 'Colombia'}, 
    {'artista': 'Bomba Estereo', 'pais': 'Colombia'}, 
    {'artista': 'Bad B', 'pais': 'Puerto Rico'}, 
    {'artista': 'Keane', 'pais': 'Reino Unido'}, 
    {'artista': 'New West', 'pais': 'Estados Unidos'}, 
    {'artista': 'Chino Pacas', 'pais': 'México'}, 
    {'artista': 'Natanael Cano', 'pais': 'México'}, 
    {'artista': 'Don Omar', 'pais': 'Puerto Rico'}, 
    {'artista': 'Lucenzo', 'pais': 'Francia'}, 
    {'artista': 'Ana Castela', 'pais': 'Brasil'}, 
    {'artista': 'AgroPlay', 'pais': 'Desconocido'}, 
    {'artista': 'Bruno Mars', 'pais': 'Estados Unidos'}, 
    {'artista': 'Big One', 'pais': 'Argentina'}, 
    {'artista': 'FMK', 'pais': 'Desconocido'}, 
    {'artista': 'Ke personajes', 'pais': 'Desconocido'}, 
    {'artista': 'Drake', 'pais': 'Canadá'}, 
    {'artista': '21 Savage', 'pais': 'Reino Unido'}, 
    {'artista': 'Justin Bieber', 'pais': 'Canadá'}, 
    {'artista': 'Chris Brown', 'pais': 'Estados Unidos'}, 
    {'artista': 'Natanael Cano', 'pais': 'México'}, 
    {'artista': 'Daddy Yankee', 'pais': 'Puerto Rico'}, 
    {'artista': 'WizKid', 'pais': 'Nigeria'}, 
    {'artista': 'Toian', 'pais': 'Desconocido'}, 
    {'artista': 'Metro Boomin', 'pais': 'Estados Unidos'}, 
    {'artista': 'Don Toliver', 'pais': 'Estados Unidos'}, 
    {'artista': 'Beam', 'pais': 'Desconocido'}, 
    {'artista': 'Simone Mendes', 'pais': 'Brasil'}, 
    {'artista': 'Tini', 'pais': 'Argentina'}, 
    {'artista': 'Lil Durk', 'pais': 'Estados Unidos'}, 
    {'artista': 'Morgan Wallen', 'pais': 'Estados Unidos'}, 
    {'artista': 'James Blake', 'pais': 'Reino Unido'}, 
    {'artista': 'Israel & Rodolffo', 'pais': 'Brasil'}, 
    {'artista': 'Mari Fernandez', 'pais': 'Brasil'}, 
    {'artista': 'Steve Lacy', 'pais': 'Estados Unidos'}, 
    {'artista': 'Beyoncé', 'pais': 'Estados Unidos'}, 
    {'artista': 'Halsey', 'pais': 'Estados Unidos'}, 
    {'artista': 'Suga', 'pais': 'Corea del Sur'}, 
    {'artista': 'Nicky Jam', 'pais': 'Estados Unidos'}, 
    {'artista': 'Feid', 'pais': 'Colombia'}, 
    {'artista': 'Sean Paul', 'pais': 'Jamaica'}, 
    {'artista': 'Drake', 'pais': 'Canadá'}, 
    {'artista': 'Beyonc�', 'pais': 'Estados Unidos'}, 
    {'artista': 'WizKid', 'pais': 'Nigeria'}, 
    {'artista': 'Toian', 'pais': 'Jamaica'}, 
    {'artista': 'Metro Boomin', 'pais': 'Estados Unidos'}, 
    {'artista': 'Don Toliver', 'pais': 'Estados Unidos'}, 
    {'artista': 'Beam', 'pais': 'Jamaica'}, 
    {'artista': 'Simone Mendes', 'pais': 'Brasil'}, 
    {'artista': 'Tini', 'pais': 'Argentina'}, 
    {'artista': 'Lil Durk', 'pais': 'Estados Unidos'}, 
    {'artista': 'Morgan Wallen', 'pais': 'Estados Unidos'}, 
    {'artista': 'James Blake', 'pais': 'Reino Unido'}, 
    {'artista': 'Israel & Rodolffo', 'pais': 'Brasil'},  
    {'artista': 'Steve Lacy', 'pais': 'Estados Unidos'}, 
    {'artista': 'Beyoncé', 'pais': 'Estados Unidos'}, 
    {'artista': 'Halsey', 'pais': 'Estados Unidos'}, 
    {'artista': 'Suga', 'pais': 'Corea del Sur'}, 
    {'artista': 'Nicky Jam', 'pais': 'Estados Unidos'}, 
    {'artista': 'Feid', 'pais': 'Colombia'}, 
    {'artista': 'Sean Paul', 'pais': 'Jamaica'}, 
    {'artista': 'Madonna', 'pais': 'Estados Unidos'}, 
    {'artista': 'Miley Cyrus', 'pais': 'Estados Unidos'}, 
    {'artista': 'Jennifer Lopez', 'pais': 'Estados Unidos'}, 
    {'artista': 'Olivia Rodrigo', 'pais': 'Estados Unidos'}, 
    {'artista': 'Luis Fonsi', 'pais': 'Puerto Rico'}, 
    {'artista': 'J Balvin', 'pais': 'Colombia'}, 
    {'artista': 'Rosalía', 'pais': 'España'}, 
    {'artista': 'El Guincho', 'pais': 'España'}, 
    {'artista': 'Mariah Carey', 'pais': 'Estados Unidos'}, 
    {'artista': 'Paulo Londra', 'pais': 'Argentina'}, 
    {'artista': 'Lizzo', 'pais': 'Estados Unidos'}, 
    {'artista': 'Swedish House Mafia', 'pais': 'Suecia'}, 
    {'artista': 'Tiesto', 'pais': 'Países Bajos'}, 
    {'artista': 'Deadmau5', 'pais': 'Canadá'}, 
    {'artista': 'Daft Punk', 'pais': 'Francia'}, 
    {'artista': 'Skrillex', 'pais': 'Estados Unidos'}, 
    {'artista': 'David Guetta', 'pais': 'Francia'}, 
    {'artista': 'Zedd', 'pais': 'Rusia'}, 
    {'artista': 'Calvin Harris', 'pais': 'Reino Unido'}, 
    {'artista': 'Marshmello', 'pais': 'Estados Unidos'}, 
    {'artista': 'The Chainsmokers', 'pais': 'Estados Unidos'}, 
    {'artista': 'Kygo', 'pais': 'Noruega'}, 
    {'artista': 'Dua Lipa', 'pais': 'Reino Unido'}, 
    {'artista': 'Anne-Marie', 'pais': 'Reino Unido'}, 
    {'artista': 'Ava Max', 'pais': 'Estados Unidos'}, 
    {'artista': 'Becky G', 'pais': 'Estados Unidos'}, 
    {'artista': 'Jessie J', 'pais': 'Reino Unido'}, 
    {'artista': 'Charlie Puth', 'pais': 'Estados Unidos'}, 
    {'artista': 'Kim Petras', 'pais': 'Alemania'}, 
    {'artista': 'Sam Smith', 'pais': 'Reino Unido'}, 
    {'artista': 'Ariana Grande', 'pais': 'Estados Unidos'}, 
    {'artista': 'Shawn Mendes', 'pais': 'Canadá'}, 
    {'artista': 'Camila Cabello', 'pais': 'Cuba'}, 
    {'artista': 'Billie Eilish', 'pais': 'Estados Unidos'}, 
    {'artista': 'Taylor Swift', 'pais': 'Estados Unidos'}, 
    {'artista': 'Katy Perry', 'pais': 'Estados Unidos'}, 
    {'artista': 'Rihanna', 'pais': 'Barbados'}, 
    {'artista': 'Beyoncé', 'pais': 'Estados Unidos'}, 
    {'artista': 'Adele', 'pais': 'Reino Unido'}, 
    {'artista': 'Lady Gaga', 'pais': 'Estados Unidos'}, 
    {'artista': 'Sia', 'pais': 'Australia'}, 
    {'artista': 'Madonna', 'pais': 'Estados Unidos'}, 
    {'artista': 'Cher', 'pais': 'Estados Unidos'}, 
    {'artista': 'Nicki Minaj', 'pais': 'Trinidad y Tobago'}, 
    {'artista': 'Cardi B', 'pais': 'Estados Unidos'}, 
    {'artista': 'Megan Thee Stallion', 'pais': 'Estados Unidos'}, 
    {'artista': 'Lil Nas X', 'pais': 'Estados Unidos'}, 
    {'artista': 'Doja Cat', 'pais': 'Estados Unidos'}, 
    {'artista': 'Lizzo', 'pais': 'Estados Unidos'}, 
    {'artista': 'Latto', 'pais': 'Estados Unidos'}, 
    {'artista': 'Eminem', 'pais': 'Estados Unidos'}, 
    {'artista': 'Dr. Dre', 'pais': 'Estados Unidos'}, 
    {'artista': 'Kendrick Lamar', 'pais': 'Estados Unidos'}, 
    {'artista': '50 Cent', 'pais': 'Estados Unidos'}, 
    {'artista': 'Jay-Z', 'pais': 'Estados Unidos'}, 
    {'artista': 'Nas', 'pais': 'Estados Unidos'}, 
    {'artista': 'Ice Cube', 'pais': 'Estados Unidos'}, 
    {'artista': 'Tupac Shakur', 'pais': 'Estados Unidos'}, 
    {'artista': 'The Notorious B.I.G.', 'pais': 'Estados Unidos'}, 
    {'artista': 'Snoop Dogg', 'pais': 'Estados Unidos'}, 
    {'artista': 'LL Cool J', 'pais': 'Estados Unidos'}, 
    {'artista': 'Busta Rhymes', 'pais': 'Estados Unidos'}, 
    {'artista': 'Eve', 'pais': 'Estados Unidos'}, 
    {'artista': 'Missy Elliott', 'pais': 'Estados Unidos'}, 
    {'artista': 'Lauryn Hill', 'pais': 'Estados Unidos'}, 
    {'artista': 'Wu-Tang Clan', 'pais': 'Estados Unidos'}, 
    {'artista': 'Public Enemy', 'pais': 'Estados Unidos'}, 
    {'artista': 'N.W.A', 'pais': 'Estados Unidos'}, 
    {'artista': 'Run-D.M.C.', 'pais': 'Estados Unidos'}, 
    {'artista': 'Beastie Boys', 'pais': 'Estados Unidos'}, 
    {'artista': 'De La Soul', 'pais': 'Estados Unidos'}, 
    {'artista': 'OutKast', 'pais': 'Estados Unidos'}, 
    {'artista': 'The Roots', 'pais': 'Estados Unidos'}, 
    {'artista': 'Fugees', 'pais': 'Estados Unidos'}, 
    {'artista': 'Black Eyed Peas', 'pais': 'Estados Unidos'}, 
    {'artista': 'D12', 'pais': 'Estados Unidos'}, 
    {'artista': 'G-Unit', 'pais': 'Estados Unidos'}, 
    {'artista': 'Mobb Deep', 'pais': 'Estados Unidos'}, 
    {'artista': 'Wu-Tang Clan', 'pais': 'Estados Unidos'}, 
    {'artista': 'Public Enemy', 'pais': 'Estados Unidos'}, 
    {'artista': 'N.W.A', 'pais': 'Estados Unidos'}, 
    {'artista': 'Run-D.M.C.', 'pais': 'Estados Unidos'}, 
    {'artista': 'Beastie Boys', 'pais': 'Estados Unidos'}, 
    {'artista': 'De La Soul', 'pais': 'Estados Unidos'}, 
    {'artista': 'OutKast', 'pais': 'Estados Unidos'}, 
    {'artista': 'The Roots', 'pais': 'Estados Unidos'}, 
    {'artista': 'Fugees', 'pais': 'Estados Unidos'}, 
    {'artista': 'Black Eyed Peas', 'pais': 'Estados Unidos'}, 
    {'artista': 'D12', 'pais': 'Estados Unidos'}, 
    {'artista': 'G-Unit', 'pais': 'Estados Unidos'}, 
    {'artista': 'Mobb Deep', 'pais': 'Estados Unidos'}, 
    {'artista': 'Dr. Dre', 'pais': 'Estados Unidos'}, 
    {'artista': 'Ice Cube', 'pais': 'Estados Unidos'}, 
    {'artista': 'Tupac Shakur', 'pais': 'Estados Unidos'}, 
    {'artista': 'The Notorious B.I.G.', 'pais': 'Estados Unidos'}, 
    {'artista': 'Snoop Dogg', 'pais': 'Estados Unidos'}, 
    {'artista': 'LL Cool J', 'pais': 'Estados Unidos'}, 
    {'artista': 'Busta Rhymes', 'pais': 'Estados Unidos'}, 
    {'artista': 'Eve', 'pais': 'Estados Unidos'}, 
    {'artista': 'Missy Elliott', 'pais': 'Estados Unidos'}, 
    {'artista': 'Lauryn Hill', 'pais': 'Estados Unidos'}, 
    {'artista': 'KRS-One', 'pais': 'Estados Unidos'}, 
    {'artista': 'MC Hammer', 'pais': 'Estados Unidos'}, 
    {'artista': 'Vanilla Ice', 'pais': 'Estados Unidos'}, 
    {'artista': 'Salt-N-Pepa', 'pais': 'Estados Unidos'}, 
    {'artista': 'MC Lyte', 'pais': 'Estados Unidos'}, 
    {'artista': 'Queen Latifah', 'pais': 'Estados Unidos'}, 
    {'artista': 'The Sugarhill Gang', 'pais': 'Estados Unidos'}, 
    {'artista': 'Grandmaster Flash and the Furious Five', 'pais': 'Estados Unidos'}, 
    {'artista': 'Afrika Bambaataa', 'pais': 'Estados Unidos'}, 
    {'artista': 'Boogie Down Productions', 'pais': 'Estados Unidos'}, 
    {'artista': 'LL Cool J', 'pais': 'Estados Unidos'}, 
    {'artista': 'Public Enemy', 'pais': 'Estados Unidos'}, 
    {'artista': 'N.W.A', 'pais': 'Estados Unidos'}, 
    {'artista': 'Run-D.M.C.', 'pais': 'Estados Unidos'}, 
    {'artista': 'Beastie Boys', 'pais': 'Estados Unidos'}, 
    {'artista': 'De La Soul', 'pais': 'Estados Unidos'}, 
    {'artista': 'OutKast', 'pais': 'Estados Unidos'}, 
    {'artista': 'The Roots', 'pais': 'Estados Unidos'}, 
    {'artista': 'Fugees', 'pais': 'Estados Unidos'}, 
    {'artista': 'Black Eyed Peas', 'pais': 'Estados Unidos'}, 
    {'artista': 'D12', 'pais': 'Estados Unidos'}, 
    {'artista': 'G-Unit', 'pais': 'Estados Unidos'}, 
    {'artista': 'Mobb Deep', 'pais': 'Estados Unidos'}, 
    {'artista': 'Dr. Dre', 'pais': 'Estados Unidos'}, 
    {'artista': 'Ice Cube', 'pais': 'Estados Unidos'}, 
    {'artista': 'Tupac Shakur', 'pais': 'Estados Unidos'}, 
    {'artista': 'The Notorious B.I.G.', 'pais': 'Estados Unidos'}, 
    {'artista': 'Snoop Dogg', 'pais': 'Estados Unidos'}, 
    {'artista': 'LL Cool J', 'pais': 'Estados Unidos'}, 
    {'artista': 'Busta Rhymes', 'pais': 'Estados Unidos'}, 
    {'artista': 'Eve', 'pais': 'Estados Unidos'}, 
    {'artista': 'Missy Elliott', 'pais': 'Estados Unidos'}, 
    {'artista': 'Lauryn Hill', 'pais': 'Estados Unidos'}, 
    {'artista': 'KRS-One', 'pais': 'Estados Unidos'}, 
    {'artista': 'MC Hammer', 'pais': 'Estados Unidos'}, 
    {'artista': 'Vanilla Ice', 'pais': 'Estados Unidos'}, 
    {'artista': 'Salt-N-Pepa', 'pais': 'Estados Unidos'}, 
    {'artista': 'MC Lyte', 'pais': 'Estados Unidos'}, 
    {'artista': 'Queen Latifah', 'pais': 'Estados Unidos'}, 
    {'artista': 'The Sugarhill Gang', 'pais': 'Estados Unidos'}, 
    {'artista': 'Grandmaster Flash and the Furious Five', 'pais': 'Estados Unidos'}, 
    {'artista': 'Afrika Bambaataa', 'pais': 'Estados Unidos'}, 
    {'artista': 'Boogie Down Productions', 'pais': 'Estados Unidos'}, 
    {'artista': 'Nas', 'pais': 'Estados Unidos'}, 
    {'artista': 'Jay-Z', 'pais': 'Estados Unidos'}, 
    {'artista': 'Kanye West', 'pais': 'Estados Unidos'}, 
    {'artista': 'Eminem', 'pais': 'Estados Unidos'}, 
    {'artista': 'Dr. Dre', 'pais': 'Estados Unidos'}, 
    {'artista': 'Kendrick Lamar', 'pais': 'Estados Unidos'}, 
    {'artista': '50 Cent', 'pais': 'Estados Unidos'}, 
    {'artista': 'J Cole', 'pais': 'Estados Unidos'}, 
    {'artista': 'Lil Wayne', 'pais': 'Estados Unidos'}, 
    {'artista': 'Nicki Minaj', 'pais': 'Estados Unidos'}, 
    {'artista': 'Snoop Dogg', 'pais': 'Estados Unidos'}, 
    {'artista': 'Missy Elliott', 'pais': 'Estados Unidos'}, 
    {'artista': 'Wu-Tang Clan', 'pais': 'Estados Unidos'}, 
    {'artista': 'Run the Jewels', 'pais': 'Estados Unidos'}, 
    {'artista': 'A Tribe Called Quest', 'pais': 'Estados Unidos'}, 
    {'artista': 'N.W.A', 'pais': 'Estados Unidos'}, 
    {'artista': 'OutKast', 'pais': 'Estados Unidos'}, 
    {'artista': 'The Notorious B.I.G.', 'pais': 'Estados Unidos'}, 
    {'artista': 'Public Enemy', 'pais': 'Estados Unidos'}, 
    {'artista': 'LL Cool J', 'pais': 'Estados Unidos'}, 
    {'artista': 'Beastie Boys', 'pais': 'Estados Unidos'}, 
    {'artista': 'De La Soul', 'pais': 'Estados Unidos'}, 
    {'artista': 'Ice Cube', 'pais': 'Estados Unidos'}, 
    {'artista': 'Wu-Tang Clan', 'pais': 'Estados Unidos'}, 
    {'artista': 'Run the Jewels', 'pais': 'Estados Unidos'}, 
    {'artista': 'A Tribe Called Quest', 'pais': 'Estados Unidos'}, 
    {'artista': 'Eminem', 'pais': 'Estados Unidos'}, 
    {'artista': 'Dr. Dre', 'pais': 'Estados Unidos'}, 
    {'artista': 'Kendrick Lamar', 'pais': 'Estados Unidos'}, 
    {'artista': '50 Cent', 'pais': 'Estados Unidos'}, 
    {'artista': 'J Cole', 'pais': 'Estados Unidos'}, 
    {'artista': 'Lil Wayne', 'pais': 'Estados Unidos'}, 
    {'artista': 'Nicki Minaj', 'pais': 'Estados Unidos'}, 
    {'artista': 'Snoop Dogg', 'pais': 'Estados Unidos'}, 
    {'artista': 'Missy Elliott', 'pais': 'Estados Unidos'}, 
    {'artista': 'Wu-Tang Clan', 'pais': 'Estados Unidos'}, 
    {'artista': 'Run the Jewels', 'pais': 'Estados Unidos'}, 
    {'artista': 'A Tribe Called Quest', 'pais': 'Estados Unidos'}, 
    {'artista': 'N.W.A', 'pais': 'Estados Unidos'}, 
    {'artista': 'OutKast', 'pais': 'Estados Unidos'}, 
    {'artista': 'The Notorious B.I.G.', 'pais': 'Estados Unidos'}, 
    {'artista': 'Public Enemy', 'pais': 'Estados Unidos'}, 
    {'artista': 'LL Cool J', 'pais': 'Estados Unidos'}, 
    {'artista': 'Beastie Boys', 'pais': 'Estados Unidos'}, 
    {'artista': 'De La Soul', 'pais': 'Estados Unidos'}, 
    {'artista': 'Ice Cube', 'pais': 'Estados Unidos'}, 
    {'artista': 'Wu-Tang Clan', 'pais': 'Estados Unidos'}, 
    {'artista': 'Run the Jewels', 'pais': 'Estados Unidos'}, 
    {'artista': 'A Tribe Called Quest', 'pais': 'Estados Unidos'}, 
    {'artista': 'N.W.A', 'pais': 'Estados Unidos'}, 
    {'artista': 'OutKast', 'pais': 'Estados Unidos'}, 
    {'artista': 'The Notorious B.I.G.', 'pais': 'Estados Unidos'}, 
    {'artista': 'Public Enemy', 'pais': 'Estados Unidos'}, 
    {'artista': 'LL Cool J', 'pais': 'Estados Unidos'}, 
    {'artista': 'Beastie Boys', 'pais': 'Estados Unidos'}, 
    {'artista': 'De La Soul', 'pais': 'Estados Unidos'}, 
    {'artista': 'Ice Cube', 'pais': 'Estados Unidos'}, 
    {'artista': 'Wu-Tang Clan', 'pais': 'Estados Unidos'}, 
    {'artista': 'Run the Jewels', 'pais': 'Estados Unidos'}, 
    {'artista': 'A Tribe Called Quest', 'pais': 'Estados Unidos'}, 
    {'artista': 'N.W.A', 'pais': 'Estados Unidos'}, 
    {'artista': 'OutKast', 'pais': 'Estados Unidos'}, 
    {'artista': 'The Notorious B.I.G.', 'pais': 'Estados Unidos'}, 
    {'artista': 'Public Enemy', 'pais': 'Estados Unidos'}, 
    {'artista': 'LL Cool J', 'pais': 'Estados Unidos'}, 
    {'artista': 'Beastie Boys', 'pais': 'Estados Unidos'}, 
    {'artista': 'De La Soul', 'pais': 'Estados Unidos'}, 
    {'artista': 'Ice Cube', 'pais': 'Estados Unidos'}, 
    {'artista': 'Wu-Tang Clan', 'pais': 'Estados Unidos'}, 
    {'artista': 'Run the Jewels', 'pais': 'Estados Unidos'}, 
    {'artista': 'A Tribe Called Quest', 'pais': 'Estados Unidos'}, 
    {'artista': 'N.W.A', 'pais': 'Estados Unidos'}, 
    {'artista': 'OutKast', 'pais': 'Estados Unidos'}, 
    {'artista': 'The Notorious B.I.G.', 'pais': 'Estados Unidos'}, 
    {'artista': 'Public Enemy', 'pais': 'Estados Unidos'}, 
    {'artista': 'LL Cool J', 'pais': 'Estados Unidos'}, 
    {'artista': 'Beastie Boys', 'pais': 'Estados Unidos'}, 
    {'artista': 'De La Soul', 'pais': 'Estados Unidos'}, 
    {'artista': 'Ice Cube', 'pais': 'Estados Unidos'}, 
    {'artista': 'Wu-Tang Clan', 'pais': 'Estados Unidos'}, 
    {'artista': 'Run the Jewels', 'pais': 'Estados Unidos'},
    {'artista': '(G)I-DLE', 'pais': 'Corea del Sur'},
    {'artista': 'Travis Scott, Young Thug, Metro Boomin', 'pais': 'Estados Unidos'},
    {'artista': 'Miguel', 'pais': 'Estados Unidos'},
    {'artista': 'The Police', 'pais': 'Reino Unido'},
    {'artista': 'Lord Huron', 'pais': 'Estados Unidos'},
    {'artista': 'Alec Benjamin', 'pais': 'Estados Unidos'},
    {'artista': 'A$AP Rocky, Metro Boomin, Roisee', 'pais': 'Estados Unidos'},
    {'artista': 'YOASOBI', 'pais': 'Japón'},
    {'artista': 'Rosa Linn', 'pais': ' Armenia'},
    {'artista': 'One Direction', 'pais': 'Reino Unido'},
    {'artista': 'Oscar Maydon, Junior H', 'pais': 'Desconocido'},
    {'artista': 'Radiohead', 'pais': 'Reino Unido'},
    {'artista': 'James Arthur', 'pais': 'Reino Unido'},
    {'artista': 'Cigarettes After Sex', 'pais': 'Estados Unidos'},
    {'artista': 'Shubh', 'pais': 'India'},
    {'artista': 'Frank Ocean', 'pais': 'Estados Unidos'},
    {'artista': 'Hozier', 'pais': 'Irlanda'},
    {'artista': 'Hotel Ugly', 'pais': 'Estados Unidos'},
    {'artista': 'Creedence Clearwater Revival', 'pais': 'Estados Unidos'},
    {'artista': 'Plan B', 'pais': 'Reino Unido'},
    {'artista': 'a-ha', 'pais': 'Noruega'},
    {'artista': 'Kodak Black, NLE Choppa, Muni Long, JVKE, Jimin', 'pais': 'Desconocido'},
    {'artista': 'Arijit Singh, Sachin-Jigar, Amitabha Bhattacharya', 'pais': 'India'},
    {'artista': 'Stray Kids', 'pais': 'Corea del Sur'},
    {'artista': 'Kaliii, Kaliii', 'pais': 'Desconocido'},
    {'artista': 'Abhijay Sharma, Riar Saab', 'pais': 'Desconocido'},
    {'artista': 'Semicenk, Do��u ', 'pais': 'Desconocido'},
    {'artista': 'JISOO', 'pais': 'Corea del Sur'},
    {'artista': 'RAYE, 070 Shake', 'pais': 'Reino Unido'},
    {'artista': 'Arcangel, Bad Bunny', 'pais': 'Puerto Rico'},
    {'artista': 'BLESSD, Peso Pluma', 'pais': 'Colombia'},
    {'artista': 'ENHYPEN', 'pais': 'Corea del Sur'},
    {'artista': 'Lil Uzi Vert', 'pais': 'Estados Unidos'},
    {'artista': 'MC Caverinha, KayBlack', 'pais': 'Brasil'},
    {'artista': 'Offset, JID', 'pais': 'Estados Unidos'},
    {'artista': 'Z�� Neto & Crist', 'pais': 'Brasil'},
    {'artista': 'Migrantes, LiL CaKe, Nico Valdi', 'pais': 'Desconocido'},
    {'artista': 'Tory Lanez', 'pais': 'Canadá'},
    {'artista': 'Joji', 'pais': 'Japón'},
    {'artista': 'Mambo Kingz, DJ Luian, Anuel Aa', 'pais': 'Puerto Rico'},
    {'artista': 'Nile Rodgers, LE SSERAFIM', 'pais': 'Desconocido'},
    {'artista': 'Agust D', 'pais': 'Corea del Sur'},
    {'artista': 'Rich The Kid, Matu�', 'pais': 'Desconocido'},
    {'artista': 'Labrinth', 'pais': 'Reino Unido'},
    {'artista': 'Lizzy McAlpine', 'pais': 'Estados Unidos'},
    {'artista': 'IVE', 'pais': 'Corea del Sur'},
    {'artista': 'sped up 8282', 'pais': 'Corea del Sur'},
    {'artista': 'Cartel De Santa, La Kelly', 'pais': 'México'},
    {'artista': 'SEVENTEEN', 'pais': 'Corea del Sur'},
    {'artista': 'NLE Choppa', 'pais': 'Estados Unidos'},
    {'artista': 'Grupo Marca Registrada, Grupo Frontera', 'pais': 'Desconocido'},
    {'artista': 'TAEYANG, Lisa', 'pais': 'Corea del Sur'},
    {'artista': 'Raim Laode', 'pais': 'Indonesia'},
    {'artista': 'Meghan Trainor', 'pais': 'Estados Unidos'},
    {'artista': 'sped up nightcore, ARIZONATEARS, Lil Uzi Vert', 'pais': 'Corea del Sur'},
    {'artista': 'TV Girl', 'pais': 'Estados Unidos'},
    {'artista': 'INTERWORLD', 'pais': 'Rusia'},
    {'artista': 'El Chachito, Junior H', 'pais': 'Desconocido'},
    {'artista': 'RM, Colde', 'pais': 'Corea del Sur'},
    {'artista': 'BLACKPINK', 'pais': 'Corea del Sur'},
    {'artista': 'Nengo Flow, Bad Bunny', 'pais': 'Puerto Rico'},
    {'artista': 'Nicky Youre, Dazy', 'pais': 'Desconocido'},
    {'artista': 'IU, Agust D', 'pais': 'Corea del Sur'},
    {'artista': 'Arcangel, Bizarrap', 'pais': 'Puerto Rico'},
    {'artista': 'Ti��sto, Tate M', 'pais': 'Países Bajos'},
    {'artista': 'NF', 'pais': 'Estados Unidos'},
    {'artista': 'Kanii, PR1ISVX', 'pais': 'Desconocido'},
    {'artista': 'Mar��lia Mendo', 'pais': 'Brasil'},
    {'artista': 'Zach Bryan', 'pais': 'Estados Unidos'},
    {'artista': 'Melanie Martinez', 'pais': 'Estados Unidos'},
    {'artista': 'Mae Stephens', 'pais': 'Reino Unido'},
    {'artista': 'Kenia OS', 'pais': 'México'},
    {'artista': 'Kordhell', 'pais': 'Turquia'},
    {'artista': 'Coolio, L.V.', 'pais': 'Estados Unidos'},
    {'artista': 'The Walters', 'pais': 'Estados Unidos'},
    {'artista': 'Mac DeMarco', 'pais': 'Canadá'},
    {'artista': 'Jack Black', 'pais': 'Estados Unidos'},
    {'artista': 'Brray, Rauw Alejandro, Lyanno', 'pais': 'Desconocido'},
    {'artista': 'Linkin Park', 'pais': 'Estados Unidos'},
    {'artista': 'Gorillaz, Bad Bunny', 'pais': 'Desconocido'},
    {'artista': 'j-hope, J. Cole', 'pais': 'Corea del Sur'},
    {'artista': 'Robin Schulz, Oliver Tree', 'pais': 'Alemania'},
    {'artista': 'Niall Horan', 'pais': 'Irlanda'},
    {'artista': 'Mahalini', 'pais': 'Indonesia'},
    {'artista': 'Arijit Singh, Sachin-Jigar', 'pais': 'India'},
    {'artista': 'ThxSoMch', 'pais': 'Canadá'},
    {'artista': 'Kaifi Khalil', 'pais': 'Pakistan'},
    {'artista': 'Leo Santana', 'pais': 'Brasil'},
    {'artista': 'Treyce', 'pais': 'Brasil'},
    {'artista': 'MC Xenon, Os Gemeos da Putaria', 'pais': 'Brasil'},
    {'artista': 'XXXTENTACION', 'pais': 'Estados Unidos'},
    {'artista': 'Yuridia, Angela Aguilar', 'pais': 'México'},
    {'artista': 'Fujii Kaze', 'pais': 'Japón'},
    {'artista': 'Wisin & Yandel, ROSAL�', 'pais': 'Puerto Rico'},
    {'artista': 'King', 'pais': 'Estados Unidos'},
    {'artista': 'P!nk', 'pais': 'Estados Unidos'},
    {'artista': 'LE SSERAFIM', 'pais': 'Corea del Sur'},
    {'artista': 'TAEYANG, Jimin', 'pais': 'Corea del Sur'},
    {'artista': 'Beach Weather', 'pais': 'Estados Unidos'},
    {'artista': 'Baby Tate', 'pais': 'Estados Unidos'},
    {'artista': 'R��', 'pais': 'Nigeria'},
    {'artista': 'Arijit Singh, Vishal Dadlani, Sukriti Kakar, Vishal-Shekhar, Shekhar Ravjiani, Kumaar', 'pais': 'India'},
    {'artista': 'Beach House', 'pais': 'Estados Unidos'},
    {'artista': 'Conan Gray', 'pais': 'Estados Unidos'},
    {'artista': 'Vishal-Shekhar, Shilpa Rao, Caralisa Monteiro, Kumaar, Vishal Dadlani, Shekhar Ravjiani', 'pais': 'India'},
    {'artista': 'TOMORROW X TOGETHER', 'pais': 'Corea del Sur'},
    {'artista': 'Mr.Kitty', 'pais': 'Estados Unidos'},
    {'artista': 'Gustavo Mioto, Mari Fernandez', 'pais': 'Brasil'},
    {'artista': 'Jack Harlow, Lil Nas X', 'pais': 'Estados Unidos'},
    {'artista': 'Elley Duh�', 'pais': 'Estados Unidos'},
    {'artista': 'Seafret', 'pais': 'Reino Unido'},
    {'artista': 'Baby Rasta, Rauw Alejandro', 'pais': 'Puerto Rico'},
    {'artista': 'DJ Escobar, MC MENOR SG, MC MENOR HR', 'pais': 'Desconocido'},
    {'artista': 'Dean Lewis', 'pais': 'Australia'},
    {'artista': 'Bellakath', 'pais': 'México'},
    {'artista': 'Travis Scott, 21 Savage, Metro Boomin', 'pais': 'Estados Unidos'},
    {'artista': 'Kate Bush', 'pais': 'Reino Unido'},
    {'artista': 'Aerosmith', 'pais': 'Estados Unidos'},
    {'artista': 'Freddie Dredd', 'pais': 'Canadá'},
    {'artista': 'Lost Frequencies, Calum Scott', 'pais': 'Bélgica'},
    {'artista': 'Twisted, Oliver Tree', 'pais': 'Estados Unidos'},
    {'artista': 'Kenshi Yonezu', 'pais': 'Japón'},
    {'artista': 'Omar Apollo', 'pais': 'Estados Unidos'},
    {'artista': 'James Hype, Miggy Dela Rosa', 'pais': 'Desconocido'},
    {'artista': 'Pritam, Arijit Singh, Amitabh Bhattacharya', 'pais': 'India'},
    {'artista': 'Styrx, utku INC, Thezth', 'pais': 'Suecia'},
    {'artista': 'Maroon 5, Wiz Khalifa', 'pais': 'Estados Unidos'},
    {'artista': 'Wham!', 'pais': 'Reino Unido'},
    {'artista': 'Brenda Lee', 'pais': 'Estados Unidos'},
    {'artista': 'Bobby Helms', 'pais': 'Estados Unidos'},
    {'artista': 'Michael Bubl�', 'pais': 'Canadá'},
    {'artista': 'Andy Williams', 'pais': 'Estados Unidos'},
    {'artista': 'Dean Martin', 'pais': 'Estados Unidos'},
    {'artista': 'Kelly Clarkson', 'pais': 'Estados Unidos'},
    {'artista': 'Jos�� Felic', 'pais': 'Portugal'},
    {'artista': 'The Ronettes', 'pais': 'Estados Unidos'},
    {'artista': 'John Lennon, The Harlem Community Choir, The Plastic Ono Band, Yoko Ono', 'pais': 'Reino Unido'},
    {'artista': 'Burl Ives', 'pais': 'Estados Unidos'},
    {'artista': 'Nat King Cole', 'pais': 'Estados Unidos'},
    {'artista': 'Paul McCartney', 'pais': 'Reino Unido'},
    {'artista': 'Band Aid', 'pais': 'Reino Unido'},
    {'artista': "Shakin' Stevens", 'pais': 'Reino Unido'},
    {'artista': 'Frank Sinatra, B. Swanson Quartet', 'pais': 'Estados Unidos'},
    {'artista': 'Bing Crosby, John Scott Trotter & His Orchestra, Ken Darby Singers', 'pais': 'Estados Unidos'},
    {'artista': 'Chris Rea', 'pais': 'Reino Unido'},
    {'artista': 'Darlene Love', 'pais': 'Estados Unidos'},
    {'artista': 'Perry Como, The Fontane Sisters, Mitchell Ayres & His Orchestra', 'pais': 'Estados Unidos'},
    {'artista': 'Britney Spears', 'pais': 'Estados Unidos'},
    {'artista': 'Mabel Matiz, Mert Demir', 'pais': 'Desconocido'},
    {'artista': 'RM', 'pais': 'Corea del Sur'},
    {'artista': 'Travis Scott, Metro Boomin', 'pais': 'Estados Unidos'},
    {'artista': 'Dj LK da Esc��cia, Tchakabum, mc jhenny, M', 'pais': 'Escocia'},
    {'artista': 'Gwen Stefani, Blake Shelton', 'pais': 'Estados Unidos'},
    {'artista': 'Chuck Berry', 'pais': 'Estados Unidos'},
    {'artista': 'Frank Sinatra', 'pais': 'Estados Unidos'},
    {'artista': 'John Legend, Metro Boomin', 'pais': 'Estados Unidos'},
    {'artista': 'Maldy, Karol G', 'pais': 'Puerto Rico'},
    {'artista': 'Gayle', 'pais': 'Reino Unido'},
    {'artista': 'Cherish, ACRAZE', 'pais': 'Estados Unidos'},
    {'artista': 'Adassa, Mauro Castillo, Stephanie Beatriz, Encanto - Cast, Rhenzy Feliz, Diane Guerrero, Carolina Gaitan', 'pais': 'Desconocido'},
    {'artista': 'Farruko', 'pais': 'Puerto Rico'},
    {'artista': 'Jaymes Young', 'pais': 'Estados Unidos'},
    {'artista': 'Ckay', 'pais': 'Nigeria'},
    {'artista': 'Jessica Darrow', 'pais': 'Cuba'},
    {'artista': 'M��ne', 'pais': 'Italia'},
    {'artista': 'Aitana, zzoilo', 'pais': 'Desconocido'},
    {'artista': 'Julieta Venegas, Bad Bunny, Tainy', 'pais': 'Desconocido'},
    {'artista': 'Lisa', 'pais': 'Tailandia'},
    {'artista': 'Ti��sto, Ava', 'pais': 'Países Bajos'},
    {'artista': 'BoyWithUke', 'pais': 'Estados Unidos'},
    {'artista': 'Em Beihold, Stephen Sanchez', 'pais': 'Desconocido'},
    {'artista': 'Travis Scott, Young Thug, Metro Boomin', 'pais': 'Estados Unidos'},
    {'artista': 'A$AP Rocky, Metro Boomin, Roisee', 'pais': 'Estados Unidos'},
    {'artista': 'Oscar Maydon, Junior H', 'pais': 'México'},
    {'artista': 'Kodak Black, NLE Choppa, Muni Long, JVKE, Jimin', 'pais': 'Estados Unidos'},
    {'artista': 'Arijit Singh, Sachin-Jigar, Amitabha Bhattacharya', 'pais': 'India'},
    {'artista': 'Kaliii, Kaliii', 'pais': 'Francia'},
    {'artista': 'Abhijay Sharma, Riar Saab', 'pais': 'India'},
    {'artista': 'Semicenk, Do��u ', 'pais': 'Turquía'},
    {'artista': 'Arcangel, Bad Bunny', 'pais': 'Desconocido'},
    {'artista': 'MC Caverinha, KayBlack', 'pais': 'Desconocido'},
    {'artista': 'Offset, JID', 'pais': 'Desconocido'},
    {'artista': 'Migrantes, LiL CaKe, Nico Valdi', 'pais': 'Argentina'},
    {'artista': 'Mambo Kingz, DJ Luian, Anuel Aa', 'pais': 'Desconocido'},
    {'artista': 'Nile Rodgers, LE SSERAFIM', 'pais': 'Estados Unidos'},
    {'artista': 'Rich The Kid, Matu�', 'pais': 'Desconocido'},
    {'artista': 'Cartel De Santa, La Kelly', 'pais': 'México'},
    {'artista': 'TAEYANG, Lisa', 'pais': 'Corea del Sur'},
    {'artista': 'sped up nightcore, ARIZONATEARS, Lil Uzi Vert', 'pais': 'Desconocido'},
    {'artista': 'El Chachito, Junior H', 'pais': 'México'},
    {'artista': 'Nengo Flow, Bad Bunny', 'pais': 'Desconocido'},
    {'artista': 'Nicky Youre, Dazy', 'pais': 'Estados Unidos'},
    {'artista': 'IU, Agust D', 'pais': 'Corea del Sur'},
    {'artista': 'Arcangel, Bizarrap', 'pais': 'Desconocido'},
    {'artista': 'Ti��sto, Tate M', 'pais': 'Desconocido'},
    {'artista': 'Kanii, PR1ISVX', 'pais': 'Desconocido'},
    {'artista': 'Coolio, L.V.', 'pais': 'Desconocido'},
    {'artista': 'Brray, Rauw Alejandro, Lyanno', 'pais': 'Desconocido'},
    {'artista': 'Gorillaz, Bad Bunny', 'pais': 'Desconocido'},
    {'artista': 'Robin Schulz, Oliver Tree', 'pais': 'Desconocido'},
    {'artista': 'Arijit Singh, Sachin-Jigar', 'pais': 'India'},
    {'artista': 'MC Xenon, Os Gemeos da Putaria', 'pais': 'Desconocido'},
    {'artista': 'Yuridia, Angela Aguilar', 'pais': 'México'},
    {'artista': 'Wisin & Yandel, ROSAL�', 'pais': 'Puerto Rico'},
    {'artista': 'TAEYANG, Jimin', 'pais': 'Corea del Sur'},
    {'artista': 'Arijit Singh, Vishal Dadlani, Sukriti Kakar, Vishal-Shekhar, Shekhar Ravjiani, Kumaar', 'pais': 'India'},
    {'artista': 'RAYE, 070 Shake', 'pais': 'Reino Unido'},
    {'artista': 'Steve Aoki, Tini, La Joaqui', 'pais': 'Estados Unidos'},
    {'artista': 'Vishal-Shekhar, Shilpa Rao, Caralisa Monteiro, Kumaar, Vishal Dadlani, Shekhar Ravjiani', 'pais': 'India'},
    {'artista': 'Gustavo Mioto, Mari Fernandez', 'pais': 'Brasil'},
    {'artista': 'Baby Rasta, Rauw Alejandro', 'pais': 'Desconocido'},
    {'artista': 'DJ Escobar, MC MENOR SG, MC MENOR HR', 'pais': 'Colombia'},
    {'artista': 'Travis Scott, 21 Savage, Metro Boomin', 'pais': 'Estados Unidos'},
    {'artista': 'Lost Frequencies, Calum Scott', 'pais': 'Desconocido'},
    {'artista': 'Twisted, Oliver Tree', 'pais': 'Desconocido'},
    {'artista': 'James Hype, Miggy Dela Rosa', 'pais': 'Desconocido'},
    {'artista': 'Pritam, Arijit Singh, Amitabh Bhattacharya', 'pais': 'India'},
    {'artista': 'Styrx, utku INC, Thezth', 'pais': 'Estados Unidos'},
    {'artista': 'Maroon 5, Wiz Khalifa', 'pais': 'Estados Unidos'},
    {'artista': 'John Lennon, The Harlem Community Choir, The Plastic Ono Band, Yoko Ono', 'pais': 'Reino Unido'},
    {'artista': 'Bing Crosby, John Scott Trotter & His Orchestra, Ken Darby Singers', 'pais': 'Estados Unidos'},
    {'artista': 'Perry Como, The Fontane Sisters, Mitchell Ayres & His Orchestra', 'pais': 'Estados Unidos'},
    {'artista': 'Mabel Matiz, Mert Demir', 'pais': 'Turquía'},
    {'artista': 'Travis Scott, Metro Boomin', 'pais': 'Estados Unidos'},
    {'artista': 'Gwen Stefani, Blake Shelton', 'pais': 'Estados Unidos'},
    {'artista': 'John Legend, Metro Boomin', 'pais': 'Desconocido'},
    {'artista': 'Maldy, Karol G', 'pais': 'Desconocido'},
    {'artista': 'Lauren Spencer Smith, Lauren Spencer Smith, Lauren Spencer Smith', 'pais': 'Canadá'},
    {'artista': 'Cherish, ACRAZE', 'pais': 'Estados Unidos'},
    {'artista': 'Adassa, Mauro Castillo, Stephanie Beatriz, Encanto - Cast, Rhenzy Feliz, Diane Guerrero, Carolina Gaitan', 'pais': 'Estados Unidos'},
    {'artista': 'Aitana, zzoilo', 'pais': 'Desconocido'},
    {'artista': 'Julieta Venegas, Bad Bunny, Tainy', 'pais': 'México'},
    {'artista': 'Ti��sto, Ava', 'pais': 'Estados Unidos'},
    {'artista': 'Juan Cruz Toledo, Huilen Toledo', 'pais': 'Argentina'},
    {'artista': 'Xam��, Gustah, Neo B', 'pais': 'Brasil'},
    {'artista': 'Emmy Meli', 'pais': 'Estados Unidos'},
    {'artista': 'Justin Quiles, Lenny Tav��rez, BL', 'pais': 'Colombia'},
    {'artista': 'Kodak Black', 'pais': 'Estados Unidos'},
    {'artista': 'Aventura, Bad Bunny', 'pais': 'Desconocido'},
    {'artista': 'THE ANXIETY, Willow, Tyler Cole', 'pais': 'Estados Unidos'},
    {'artista': 'Stromae', 'pais': 'Bélgica'},
    {'artista': 'NEIKED, Mae Muller, Polo G', 'pais': 'Desconocido'},
    {'artista': 'Oliver Tree', 'pais': 'Desconocido'},
    {'artista': 'Young Thug, Future, Gunna', 'pais': 'Desconocido'},
    {'artista': 'Jnr Choi', 'pais': 'Corea del Sur'},
    {'artista': 'Trueno, Tiago pzk', 'pais': 'Desconocido'},
    {'artista': 'Sech, Bad Bunny, Mora', 'pais': 'Desconocido'},
    {'artista': 'Ti��sto, Kar', 'pais': 'Desconocido'},
    {'artista': 'Edison Lighthouse', 'pais': 'Reino Unido'},
    {'artista': 'Olga Merediz, Stephanie Beatriz, Encanto - Cast', 'pais': 'Desconocido'},
    {'artista': 'Surf Curse', 'pais': 'Desconocido'},
    {'artista': 'Jason Derulo', 'pais': 'Desconocido'},
    {'artista': '24kgoldn, Iann Dior', 'pais': 'Desconocido'},
    {'artista': 'Stephanie Beatriz, Diane Guerrero', 'pais': 'Desconocido'},
    {'artista': 'Trueno', 'pais': 'Desconocido'},
    {'artista': 'Playboi Carti', 'pais': 'Desconocido'},
    {'artista': 'Maluma', 'pais': 'Colombia'},
    {'artista': 'Prezioso, Gabry Ponte, LUM!X', 'pais': 'Desconocido'},
    {'artista': 'Ti��', 'pais': 'Desconocido'},
    {'artista': 'Mar��lia Mendon��a, George Henrique &', 'pais': 'Brasil'},
    {'artista': 'TWICE', 'pais': 'Corea del Sur'},
    {'artista': 'Giveon', 'pais': 'Desconocido'},
    {'artista': 'Charli XCX, Jax Jones, Joel Corry, Saweetie', 'pais': 'Desconocido'},
    {'artista': 'SALES', 'pais': 'Desconocido'},
    {'artista': 'Sleepy hallow', 'pais': 'Desconocido'},
    {'artista': 'Masked Wolf', 'pais': 'Desconocido'},
    {'artista': 'Anuel Aa, Jhay Cortez', 'pais': 'Desconocido'},
    {'artista': 'NIKI', 'pais': 'Desconocido'},
    {'artista': 'Tate McRae', 'pais': 'Desconocido'},
    {'artista': 'Avicii', 'pais': 'Suecia'},
    {'artista': 'Tones and I', 'pais': 'Australia'},
    {'artista': 'Juice WRLD', 'pais': 'Estados Unidos'},
    {'artista': 'John Legend', 'pais': 'Estados Unidos'},
    {'artista': 'Nirvana', 'pais': 'Estados Unidos'},
    {'artista': 'Duncan Laurence', 'pais': 'Países Bajos'},
    {'artista': 'SiM', 'pais': 'Japón'},
    {'artista': 'The Killers', 'pais': 'Estados Unidos'},
    {'artista': 'Riton, Nightcrawlers, Mufasa & Hypeman, Dopamine', 'pais': 'Desconocido'},
    {'artista': 'Polo G', 'pais': 'Desconocido'},
    {'artista': 'Maroon 5', 'pais': 'Estados Unidos'},
    {'artista': 'Arcangel, De La Ghetto, Justin Quiles, Lenny Tav��rez, Sech, Dalex, Dimelo Flow, Rich Music', 'pais': 'Desconocido'},
    {'artista': 'Mar��lia Mendon��a, Maiara &', 'pais': 'Brasil'},
    {'artista': 'Anuel Aa, Myke Towers, Jhay Cortez', 'pais': 'Desconocido'},
    {'artista': 'Dove Cameron', 'pais': 'Estados Unidos'},
    {'artista': 'Mahmood, Blanco', 'pais': 'Italia'},
    {'artista': 'Tate McRae', 'pais': 'Desconocido'},
    {'artista': 'Yung Lean', 'pais': 'Suecia'},
    {'artista': 'The Rare Occasions', 'pais': 'Desconocido'},
    {'artista': 'Intense, AP Dhillon, Gurinder Gill', 'pais': 'Desconocido'},
    {'artista': 'Juice WRLD', 'pais': 'Estados Unidos'},
    {'artista': 'Luude, Colin Hay', 'pais': 'Desconocido'},
    {'artista': 'GODZZ__-, Zakaria', 'pais': 'Desconocido'},
    {'artista': 'Chase Atlantic', 'pais': 'Australia'},
    {'artista': 'Em Beihold', 'pais': 'Irán'},
    {'artista': 'Mainstreet, Chefin', 'pais': 'Desconocido'},
    {'artista': 'Alvaro Diaz, Rauw Alejandro', 'pais': 'Desconocido'},
    {'artista': 'Z�� Fe', 'pais': 'Desconocido'},
    {'artista': 'Muni Long', 'pais': 'Desconocido'},
    {'artista': 'Vundabar', 'pais': 'Desconocido'},
    {'artista': 'V', 'pais': 'Desconocido'},
    {'artista': 'Mar��lia Mendon��a, Hugo & G', 'pais': 'Brasil'},
    {'artista': 'Nirvana', 'pais': 'Estados Unidos'},
    {'artista': 'Cris Mj', 'pais': 'Desconocido'},
    {'artista': 'Anitta', 'pais': 'Brasil'},
    {'artista': 'Tulus', 'pais': 'Indonesia'},
    {'artista': 'Zion & Lennox', 'pais': 'Puerto Rico'},
    {'artista': 'Residente, Bizarrap', 'pais': 'Desconocido'},
    {'artista': 'Eden Mu��', 'pais': 'Desconocido'},
    {'artista': 'Treasure', 'pais': 'Desconocido'},
    {'artista': 'Christian Nodal', 'pais': 'México'},
    {'artista': 'Kevin Gates, Juicy J', 'pais': 'Desconocido'},
    {'artista': 'Tyga, Doja Cat', 'pais': 'Desconocido'},
    {'artista': 'Queen', 'pais': 'Reino Unido'},
    {'artista': 'Avicii', 'pais': 'Suecia'},
    {'artista': 'YEAT', 'pais': 'Desconocido'},
    {'artista': 'C. Tangana', 'pais': 'España'},
    {'artista': 'NMIXX', 'pais': 'Corea del Sur'},
    {'artista': 'Gotye, Kimbra', 'pais': 'Australia'},
    {'artista': 'AnnenMayKantereit, Giant Rooks', 'pais': 'Alemania'},
    {'artista': 'Jack Harlow', 'pais': 'Estados Unidos'},
    {'artista': 'Danny Ocean', 'pais': 'Desconocido'},
    {'artista': 'Lil Tjay', 'pais': 'Desconocido'},
    {'artista': 'Willow', 'pais': 'Desconocido'},
    {'artista': 'Demi Lovato', 'pais': 'Estados Unidos'},
    {'artista': 'Matu��, Wiu, ', 'pais': 'Estados Unidos'},
    {'artista': 'De La Ghetto, Duki, Quevedo', 'pais': 'España'},
    {'artista': 'Lil Baby', 'pais': 'Desconocido'},
    {'artista': 'Ak4:20, Cris Mj, Pailita', 'pais': 'Chile'},
    {'artista': 'Lu��sa Sonza, MC Frog, Dj Gabriel do Borel, Davi K', 'pais': 'Brasil'},
    {'artista': 'teto', 'pais': 'Desconocido'},
    {'artista': 'Blackbear, BoyWithUke', 'pais': 'Estados Unidos'},
    {'artista': 'Pharrell Williams, Nile Rodgers, Daft Punk', 'pais': 'Estados Unidos'},
    {'artista': "Jordan Fisher, Josh Levi, Finneas O'Connell, 4*TOWN (From Disney and Pixar���s Turning Red), Topher Ngo, Grayson Vill", 'pais': 'Estados Unidos'},
    {'artista': 'BIGBANG', 'pais': 'Corea del Sur'},
    {'artista': 'Tony Dize, Bad Bunny', 'pais': 'Desconocido'},
    {'artista': 'Buscabulla, Bad Bunny', 'pais': 'Desconocido'},
    {'artista': 'Polima WestCoast, Pailita', 'pais': 'Desconocido'},
    {'artista': 'Panic! At The Disco', 'pais': 'Estados Unidos'},
    {'artista': 'PSY, Suga', 'pais': 'Corea del Sur'},
    {'artista': 'Benson Boone', 'pais': 'Desconocido'},
    {'artista': 'KALUSH', 'pais': 'Desconocido'},
    {'artista': 'Luciano', 'pais': 'Alemania'},
    {'artista': 'Shae Gill, Ali Sethi', 'pais': 'Desconocido'},
    {'artista': 'Sech, Mora', 'pais': 'Desconocido'},
    {'artista': 'MNEK, Jax Jones', 'pais': 'Desconocido'},
    {'artista': 'Ugly Dray, Tesla Jnr', 'pais': 'Desconocido'},
    {'artista': 'Jessi', 'pais': 'Desconocido'},
    {'artista': 'Chanel', 'pais': 'Desconocido'},
    {'artista': 'Leah Kate', 'pais': 'Desconocido'},
    {'artista': 'Sam Ryder', 'pais': 'Desconocido'},
    {'artista': 'HA SUNG WOON, Jimin', 'pais': 'Corea del Sur'},
    {'artista': 'The Goo Goo Dolls', 'pais': 'Estados Unidos'},
    {'artista': 'Kevin Kaarl', 'pais': 'Desconocido'},
    {'artista': 'Suki Waterhouse', 'pais': 'Desconocido'},
    {'artista': 'Pharrell Williams, Tyler, The Creator, 21 Savage', 'pais': 'Desconocido'},
    {'artista': 'Nengo Flow, Anuel Aa, Chris Jedi, Chencho Corleone', 'pais': 'Desconocido'},
    {'artista': 'Musical Youth', 'pais': 'Jamaica'},
    {'artista': 'BYOR, Imanbek', 'pais': 'Desconocido'},
    {'artista': 'Sleepy hallow, 347aidan', 'pais': 'Desconocido'},
    {'artista': 'Paloma Faith', 'pais': 'Reino Unido'},
    {'artista': 'Childish Gambino', 'pais': 'Estados Unidos'},
    {'artista': 'Sidhu Moose Wala', 'pais': 'India'},
    {'artista': 'Keisya Levronka', 'pais': 'Indonesia'},
    {'artista': 'Victor Cibrian', 'pais': 'Desconocido'},
    {'artista': 'Metallica', 'pais': 'Estados Unidos'},
    {'artista': 'De La Ghetto, Feid, Polima WestCoast, Paloma Mami, Pailita', 'pais': 'Desconocido'},
    {'artista': 'Yung Gravy', 'pais': 'Desconocido'},
    {'artista': 'Lasso', 'pais': 'Venezuela'},
    {'artista': 'Nayeon', 'pais': 'Corea del Sur'},
    {'artista': 'Sch��rze, DJ R', 'pais': 'Desconocido'},
    {'artista': "Guns N' Roses", 'pais': 'Estados Unidos'},
    {'artista': 'L7nnon, DJ Biel do Furduncinho, Bianca', 'pais': 'Desconocido'},
    {'artista': 'Anitta, Tini, Becky G', 'pais': 'Brasil'},
    {'artista': 'Nessa Barrett', 'pais': 'Desconocido'},
    {'artista': 'LF System', 'pais': 'Desconocido'},
    {'artista': 'Mc Vitin Da Igrejinha, MC Tairon, DJ Win', 'pais': 'Desconocido'},
    {'artista': 'Rels B', 'pais': 'Desconocido'},
    {'artista': 'Luar La L', 'pais': 'Desconocido'},
    {'artista': 'Ghost', 'pais': 'Desconocido'},
    {'artista': 'Rex Orange County', 'pais': 'Reino Unido'},
    {'artista': 'Sofia Carson', 'pais': 'Estados Unidos'},
    {'artista': 'Grupo Marca Registrada, Junior H', 'pais': 'México'},
    {'artista': 'Luis R Conriquez, La Adictiva', 'pais': 'Desconocido'},
    {'artista': 'Melody, Ana Castela, Dj Chris No Beat', 'pais': 'Desconocido'},
    {'artista': 'Elton John, Britney Spears', 'pais': 'Desconocido'},
    {'artista': 'Interplanetary Criminal, Eliza Rose', 'pais': 'Desconocido'},
    {'artista': 'TWICE', 'pais': 'Corea del Sur'},
    {'artista': 'Armani White', 'pais': 'Desconocido'},
    {'artista': 'Oxlade', 'pais': 'Nigeria'},
    {'artista': 'YEAT', 'pais': 'Desconocido'},
    {'artista': 'PnB Rock', 'pais': 'Desconocido'},
    {'artista': 'Ovy On The Drums, Quevedo', 'pais': 'Desconocido'},
    {'artista': 'Lil Yachty', 'pais': 'Desconocido'},
    {'artista': 'Fran C, Polima WestCoast, Nickoog Clk, Pablito Pesadilla', 'pais': 'Desconocido'},
    {'artista': 'Southstar', 'pais': 'Desconocido'},
    {'artista': 'girl in red', 'pais': 'Desconocido'},
    {'artista': 'Rosa Walton, Hallie Coggins', 'pais': 'Desconocido'},
    {'artista': 'Lil Baby', 'pais': 'Desconocido'},
    {'artista': 'Luciano, Aitch, B�', 'pais': 'Desconocido'},
    {'artista': 'MC Ryan SP, Love Funk, Mc Paiva ZS', 'pais': 'Desconocido'},
    {'artista': 'Ludwig Goransson, Foudeqush', 'pais': 'Desconocido'},
    {'artista': 'Jin', 'pais': 'Corea del Sur'},
    {'artista': 'Selena Gomez', 'pais': 'Estados Unidos'},
    {'artista': 'Travis Scott', 'pais': 'Estados Unidos'},
    {'artista': 'Young Thug', 'pais': 'Estados Unidos'},
    {'artista': 'Metro Boomin', 'pais': 'Estados Unidos'},
    {'artista': 'A$AP Rocky', 'pais': 'Estados Unidos'},
    {'artista': 'Roisee', 'pais': 'Desconocido'},
    {'artista': 'Arijit Singh', 'pais': 'India'},
    {'artista': 'Sachin-Jigar', 'pais': 'India'},
    {'artista': 'Amitabha Bhattacharya', 'pais': 'India'},
    {'artista': 'Riar Saab', 'pais': 'Desconocido'},
    {'artista': 'Do��u', 'pais': 'Desconocido'},
    {'artista': '070 Shake', 'pais': 'Desconocido'},
    {'artista': 'Arcangel', 'pais': 'Puerto Rico'},
    {'artista': 'Bad Bunny', 'pais': 'Puerto Rico'},
    {'artista': 'BLESSD', 'pais': 'Colombia'},
    {'artista': 'Peso Pluma', 'pais': 'México'},
    {'artista': 'MC Caverinha', 'pais': 'Brasil'},
    {'artista': 'KayBlack', 'pais': 'Desconocido'},
    {'artista': 'Offset', 'pais': 'Estados Unidos'},
    {'artista': 'JID', 'pais': 'Estados Unidos'},
    {'artista': 'Migrantes', 'pais': 'Argentina'},
    {'artista': 'LiL CaKe', 'pais': 'Desconocido'},
    {'artista': 'Nico Valdi', 'pais': 'Desconocido'},
    {'artista': 'Mambo Kingz', 'pais': 'Puerto Rico'},
    {'artista': 'DJ Luian', 'pais': 'Puerto Rico'},
    {'artista': 'Anuel Aa', 'pais': 'Puerto Rico'},
    {'artista': 'Nile Rodgers', 'pais': 'Estados Unidos'},
    {'artista': 'Rich The Kid', 'pais': 'Estados Unidos'},
    {'artista': 'Matu�', 'pais': 'Desconocido'},
    {'artista': 'Cartel De Santa', 'pais': 'México'},
    {'artista': 'La Kelly', 'pais': 'Desconocido'},
    {'artista': 'TAEYANG', 'pais': 'Corea del Sur'},
    {'artista': 'ARIZONATEARS', 'pais': 'Desconocido'},
    {'artista': 'Lil Uzi Vert', 'pais': 'Estados Unidos'},
    {'artista': 'Nengo Flow', 'pais': 'Puerto Rico'},
    {'artista': 'Dazy', 'pais': 'Desconocido'},
    {'artista': 'IU', 'pais': 'Corea del Sur'},
    {'artista': 'Agust D', 'pais': 'Corea del Sur'},
    {'artista': 'Bizarrap', 'pais': 'Argentina'},
    {'artista': 'Ti��sto', 'pais': 'Países Bajos'},
    {'artista': 'Tate M', 'pais': 'Canadá'},
    {'artista': 'Kanii', 'pais': 'Estados Unidos'},
    {'artista': 'PR1ISVX', 'pais': 'Desconocido'},
    {'artista': 'Coolio', 'pais': 'Estados Unidos'},
    {'artista': 'L.V.', 'pais': 'Desconocido'},
    {'artista': 'Brray', 'pais': 'Puerto Rico'},
    {'artista': 'Rauw Alejandro', 'pais': 'Puerto Rico'},
    {'artista': 'Lyanno', 'pais': 'Puerto Rico'},
    {'artista': 'Gorillaz', 'pais': 'Reino Unido'},
    {'artista': 'Robin Schulz', 'pais': 'Alemania'},
    {'artista': 'Oliver Tree', 'pais': 'Estados Unidos'},
    {'artista': 'Os Gemeos da Putaria', 'pais': 'Desconocido'},
    {'artista': 'Yuridia', 'pais': 'México'},
    {'artista': 'Angela Aguilar', 'pais': 'México'},
    {'artista': 'Wisin & Yandel', 'pais': 'Puerto Rico'},
    {'artista': 'Jimin', 'pais': 'Corea del Sur'},
    {'artista': 'Vishal Dadlani', 'pais': 'India'},
    {'artista': 'Sukriti Kakar', 'pais': 'India'},
    {'artista': 'Vishal-Shekhar', 'pais': 'India'},
    {'artista': 'Shekhar Ravjiani', 'pais': 'India'},
    {'artista': 'Kumaar', 'pais': 'India'},
    {'artista': 'Steve Aoki', 'pais': 'Estados Unidos'},
    {'artista': 'Tini', 'pais': 'Argentina'},
    {'artista': 'La Joaqui', 'pais': 'Argentina'},
    {'artista': 'Gustavo Mioto', 'pais': 'Brasil'},
    {'artista': 'Mari Fernandez', 'pais': 'Desconocido'},
    {'artista': 'Baby Rasta', 'pais': 'Puerto Rico'},
    {'artista': 'DJ Escobar', 'pais': 'Colombia'},
    {'artista': 'MC MENOR SG', 'pais': 'Brasil'},
    {'artista': 'MC MENOR HR', 'pais': 'Brasil'},
    {'artista': 'Lost Frequencies', 'pais': 'Bélgica'},
    {'artista': 'Calum Scott', 'pais': 'Reino Unido'},
    {'artista': 'Twisted', 'pais': 'Estados Unidos'},
    {'artista': 'James Hype', 'pais': 'Reino Unido'},
    {'artista': 'Miggy Dela Rosa', 'pais': 'Desconocido'},
    {'artista': 'Pritam', 'pais': 'India'},
    {'artista': 'Styrx', 'pais': 'Estados Unidos'},
    {'artista': 'utku INC', 'pais': 'Desconocido'},
    {'artista': 'Thezth', 'pais': 'Desconocido'},
    {'artista': 'John Lennon', 'pais': 'Reino Unido'},
    {'artista': 'The Harlem Community Choir', 'pais': 'Desconocido'},
    {'artista': 'The Plastic Ono Band', 'pais': 'Desconocido'},
    {'artista': 'Yoko Ono', 'pais': 'Desconocido'},
    {'artista': 'Bing Crosby', 'pais': 'Estados Unidos'},
    {'artista': 'John Scott Trotter & His Orchestra', 'pais': 'Desconocido'},
    {'artista': 'Ken Darby Singers', 'pais': 'Desconocido'},
    {'artista': 'Perry Como', 'pais': 'Estados Unidos'},
    {'artista': 'The Fontane Sisters', 'pais': 'Desconocido'},
    {'artista': 'Mitchell Ayres & His Orchestra', 'pais': 'Desconocido'},
    {'artista': 'Mabel Matiz', 'pais': 'Turquía'},
    {'artista': 'Mert Demir', 'pais': 'Desconocido'},
    {'artista': 'Travis Scott', 'pais': 'Estados Unidos'},
    {'artista': 'Dj LK da Esc��cia', 'pais': 'Escocia'},
    {'artista': 'Tchakabum', 'pais': 'Desconocido'},
    {'artista': 'mc jhenny', 'pais': 'Desconocido'},
    {'artista': 'M', 'pais': 'Desconocido'},
    {'artista': 'Gwen Stefani', 'pais': 'Estados Unidos'},
    {'artista': 'Blake Shelton', 'pais': 'Estados Unidos'},
    {'artista': 'Maldy', 'pais': 'Puerto Rico'},
    {'artista': 'Karol G', 'pais': 'Colombia'},
    {'artista': 'Cherish', 'pais': 'Estados Unidos'},
    {'artista': 'ACRAZE', 'pais': 'Desconocido'},
    {'artista': 'Adassa', 'pais': 'Estados Unidos'},
    {'artista': 'Mauro Castillo', 'pais': 'Desconocido'},
    {'artista': 'Stephanie Beatriz', 'pais': 'Estados Unidos'},
    {'artista': 'Encanto - Cast', 'pais': 'Desconocido'},
    {'artista': 'Rhenzy Feliz', 'pais': 'Desconocido'},
    {'artista': 'Diane Guerrero', 'pais': 'Estados Unidos'},
    {'artista': 'Carolina Gaitan', 'pais': 'Colombia'},
    {'artista': 'Aitana', 'pais': 'España'},
    {'artista': 'zzoiIo', 'pais': 'Desconocido'},
    {'artista': 'Julieta Venegas', 'pais': 'México'},
    {'artista': 'Tainy', 'pais': 'Puerto Rico'},
    {'artista': 'Ti��sto', 'pais': 'Países Bajos'},
    {'artista': 'Ava', 'pais': 'Desconocido'},
    {'artista': 'Huilen Toledo', 'pais': 'Desconocido'},
    {'artista': 'Gustah', 'pais': 'Desconocido'},
    {'artista': 'Neo B', 'pais': 'Desconocido'},
    {'artista': 'Justin Quiles', 'pais': 'Puerto Rico'},
    {'artista': 'Lenny Tav��rez', 'pais': 'Puerto Rico'},
    {'artista': 'BL', 'pais': 'Desconocido'},
    {'artista': 'Aventura', 'pais': 'República Dominicana'},
    {'artista': 'Willow', 'pais': 'Estados Unidos'},
    {'artista': 'Tyler Cole', 'pais': 'Desconocido'},
    {'artista': 'NEIKED', 'pais': 'Suecia'},
    {'artista': 'Mae Muller', 'pais': 'Reino Unido'},
    {'artista': 'Polo G', 'pais': 'Estados Unidos'},
    {'artista': 'Sech', 'pais': 'Panamá'},
    {'artista': 'Mora', 'pais': 'Desconocido'},
    {'artista': 'Kar', 'pais': 'Desconocido'},
    {'artista': 'Olga Merediz', 'pais': 'Desconocido'},
    {'artista': '24kgoldn', 'pais': 'Estados Unidos'},
    {'artista': 'Iann Dior', 'pais': 'Estados Unidos'},
    {'artista': 'Stephanie Beatriz', 'pais': 'Estados Unidos'},
    {'artista': 'Prezioso', 'pais': 'Italia'},
    {'artista': 'Gabry Ponte', 'pais': 'Italia'},
    {'artista': 'LUM!X', 'pais': 'Desconocido'},
    {'artista': 'Mar��lia Mendon��a', 'pais': 'Brasil'},
    {'artista': 'George Henrique &', 'pais': 'Desconocido'},
    {'artista': 'Charli XCX', 'pais': 'Reino Unido'},
    {'artista': 'Jax Jones', 'pais': 'Reino Unido'},
    {'artista': 'Joel Corry', 'pais': 'Reino Unido'},
    {'artista': 'Saweetie', 'pais': 'Estados Unidos'},
    {'artista': 'Anuel Aa', 'pais': 'Puerto Rico'},
    {'artista': 'Jhay Cortez', 'pais': 'Puerto Rico'},
    {'artista': 'MC Xenon', 'pais': 'Brasil'},
    {'artista': 'Os Gemeos da Putaria', 'pais': 'Brasil'},
    {'artista': 'Riton', 'pais': 'Desconocido'},
    {'artista': 'Nightcrawlers', 'pais': 'Desconocido'},
    {'artista': 'Mufasa & Hypeman', 'pais': 'Desconocido'},
    {'artista': 'Dopamine', 'pais': 'Desconocido'},
    {'artista': 'Mahmood', 'pais': 'Italia'},
    {'artista': 'Blanco', 'pais': 'Desconocido'},
    {'artista': 'Intense', 'pais': 'Desconocido'},
    {'artista': 'AP Dhillon', 'pais': 'Desconocido'},
    {'artista': 'Gurinder Gill', 'pais': 'Desconocido'},
    {'artista': 'Luude', 'pais': 'Desconocido'},
    {'artista': 'Colin Hay', 'pais': 'Desconocido'},
    {'artista': 'GODZZ__-', 'pais': 'Desconocido'},
    {'artista': 'Zakaria', 'pais': 'Desconocido'},
    {'artista': 'Mainstreet', 'pais': 'Desconocido'},
    {'artista': 'Chefin', 'pais': 'Desconocido'},
    {'artista': 'Alvaro Diaz', 'pais': 'Desconocido'},
    {'artista': 'Rauw Alejandro', 'pais': 'Puerto Rico'},
    {'artista': 'Residente', 'pais': 'Puerto Rico'},
    {'artista': 'Bizarrap', 'pais': 'Argentina'},
    {'artista': 'Kevin Gates', 'pais': 'Estados Unidos'},
    {'artista': 'Juicy J', 'pais': 'Estados Unidos'},
    {'artista': 'Tyga', 'pais': 'Estados Unidos'},
    {'artista': 'Doja Cat', 'pais': 'Estados Unidos'},
    {'artista': 'Gotye', 'pais': 'Australia'},
    {'artista': 'Kimbra', 'pais': 'Nueva Zelanda'},
    {'artista': 'AnnenMayKantereit', 'pais': 'Alemania'},
    {'artista': 'Giant Rooks', 'pais': 'Alemania'},
    {'artista': 'Matu��', 'pais': 'Desconocido'},
    {'artista': 'Wiu', 'pais': 'Desconocido'},
    {'artista': 'De La Ghetto', 'pais': 'Puerto Rico'},
    {'artista': 'Duki', 'pais': 'Argentina'},
    {'artista': 'Ak4:20', 'pais': 'Desconocido'},
    {'artista': 'Cris Mj', 'pais': 'Desconocido'},
    {'artista': 'Pailita', 'pais': 'Desconocido'},
    {'artista': 'Lu��sa Sonza', 'pais': 'Brasil'},
    {'artista': 'MC Frog', 'pais': 'Desconocido'},
    {'artista': 'Dj Gabriel do Borel', 'pais': 'Desconocido'},
    {'artista': 'Davi K', 'pais': 'Desconocido'},
    {'artista': 'Blackbear', 'pais': 'Estados Unidos'},
    {'artista': 'Pharrell Williams', 'pais': 'Estados Unidos'},
    {'artista': 'Nile Rodgers', 'pais': 'Estados Unidos'},
    {'artista': 'Daft Punk', 'pais': 'Francia'},
    {'artista': 'Jordan Fisher', 'pais': 'Estados Unidos'},
    {'artista': 'Josh Levi', 'pais': 'Estados Unidos'},
    {'artista': 'Finneas O Connell', 'pais': 'Estados Unidos'},
    {'artista': '4*TOWN', 'pais': 'Desconocido'},
    {'artista': 'Topher Ngo', 'pais': 'Desconocido'},
    {'artista': 'Grayson Vill', 'pais': 'Desconocido'},
    {'artista': 'Tony Dize', 'pais': 'Puerto Rico'},
    {'artista': 'Buscabulla', 'pais': 'Puerto Rico'},
    {'artista': 'Polima WestCoast', 'pais': 'Desconocido'},
    {'artista': 'Pailita', 'pais': 'Desconocido'},
    {'artista': 'PSY', 'pais': 'Corea del Sur'},
    {'artista': 'Suga', 'pais': 'Corea del Sur'},
    {'artista': 'Shae Gill', 'pais': 'Desconocido'},
    {'artista': 'Ali Sethi', 'pais': 'Pakistán'},
    {'artista': 'MNEK', 'pais': 'Reino Unido'},
    {'artista': 'Jax Jones', 'pais': 'Reino Unido'},
    {'artista': 'Ugly Dray', 'pais': 'Desconocido'},
    {'artista': 'Tesla Jnr', 'pais': 'Desconocido'},
    {'artista': 'HA SUNG WOON', 'pais': 'Corea del Sur'},
    {'artista': 'Jimin', 'pais': 'Corea del Sur'},
    {'artista': 'Pharrell Williams', 'pais': 'Estados Unidos'},
    {'artista': 'Tyler', 'pais': 'Estados Unidos'},
    {'artista': 'The Creator', 'pais': 'Estados Unidos'},
    {'artista': '21 Savage', 'pais': 'Reino Unido'},
    {'artista': 'BYOR', 'pais': 'Desconocido'},
    {'artista': 'Imanbek', 'pais': 'Kazajistán'},
    {'artista': 'De La Ghetto', 'pais': 'Puerto Rico'},
    {'artista': 'Feid', 'pais': 'Colombia'},
    {'artista': 'Polima WestCoast', 'pais': 'Desconocido'},
    {'artista': 'Paloma Mami', 'pais': 'Chile'},
    {'artista': 'Pailita', 'pais': 'Desconocido'},
    {'artista': 'Sch��rze', 'pais': 'Desconocido'},
    {'artista': 'DJ R', 'pais': 'Desconocido'},
    {'artista': 'L7nnon', 'pais': 'Brasil'},
    {'artista': 'DJ Biel do Furduncinho', 'pais': 'Brasil'},
    {'artista': 'Bianca', 'pais': 'Desconocido'},
    {'artista': 'Mc Vitin Da Igrejinha', 'pais': 'Brasil'},
    {'artista': 'MC Tairon', 'pais': 'Desconocido'},
    {'artista': 'DJ Win', 'pais': 'Desconocido'},
    {'artista': 'Luis R Conriquez', 'pais': 'Desconocido'},
    {'artista': 'La Adictiva', 'pais': 'México'},
    {'artista': 'Melody', 'pais': 'España'},
    {'artista': 'Dj Chris No Beat', 'pais': 'Desconocido'},
    {'artista': 'Elton John', 'pais': 'Reino Unido'},
    {'artista': 'Britney Spears', 'pais': 'Estados Unidos'},
    {'artista': 'Interplanetary Criminal', 'pais': 'Desconocido'},
    {'artista': 'Eliza Rose', 'pais': 'Desconocido'},
    {'artista': 'Ovy On The Drums', 'pais': 'Colombia'},
    {'artista': 'Fran C', 'pais': 'Desconocido'},
    {'artista': 'Nickoog Clk', 'pais': 'Desconocido'},
    {'artista': 'Pablito Pesadilla', 'pais': 'Desconocido'},
    {'artista': 'Rosa Walton', 'pais': 'Reino Unido'},
    {'artista': 'Hallie Coggins', 'pais': 'Desconocido'},
    {'artista': 'MC Ryan SP', 'pais': 'Desconocido'},
    {'artista': 'Love Funk', 'pais': 'Desconocido'},
    {'artista': 'Mc Paiva ZS', 'pais': 'Brasil'},
    {'artista': 'Ludwig Goransson', 'pais': 'Suecia'}


]


artist_country_map = dict()
for d in data_dict:
    artist_country_map[d['artista'].lower()] = d['pais']
artist_country_map
# Out:
# {'latto jung kook': 'Estados Unidos',
#  'burna boy': 'Nigeria',
#  'myke towers': 'Puerto Rico',
#  'olivia rodrigo': 'Estados Unidos',
#  'taylor swift': 'Estados Unidos',
#  'bad bunny': 'Puerto Rico',
#  'dave central cee': 'Reino Unido',
#  'eslabon armado peso pluma': 'Estados Unidos',
#  'quevedo': 'España',
#  'gunna': 'Estados Unidos',
#  'peso pluma yng lvcas': 'Mexico',
#  'bad bunny grupo frontera': 'Puerto Rico',
#  'newjeans': 'Corea del Sur',
#  'miley cyrus': 'Estados Unidos',
#  'david kushner': 'Estados Unidos',
#  'harry styles': 'Reino Unido',
#  'sza': 'Estados Unidos',
#  'fifty fifty': 'Corea del Sur',
#  'billie eilish': 'Estados Unidos',
#  'feid young miko': 'Colombia',
#  'jimin': 'Corea del Sur',
#  'gabito ballesteros junior h peso pluma': 'México',
#  'arctic monkeys': 'Reino Unido',
#  'bizarrap peso pluma': 'Argentina',
#  'the weeknd madonna playboi carti': 'Canadá',
#  'fuerza regida': 'México',
#  'r��ma selena g': 'Nigeria',
# ...

# %%
limpiar(spotify)

# %%
spotify.head()
# Out:
#                              trackname     artist(s)name  artistcount  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook            2
# 1                                 LALA       Myke Towers            1
# 2                              vampire    Olivia Rodrigo            1
# 3                         Cruel Summer      Taylor Swift            1
# 4                       WHERE SHE GOES         Bad Bunny            1
#
#    releasedyear  releasedmonth  releasedday  inspotifyplaylists  \
# 0          2023              7           14                 553
# 1          2023              3           23                1474
# 2          2023              6           30                1397
# 3          2019              8           23                7858
# 4          2023              5           18                3133
#
#    inspotifycharts    streams  inappleplaylists  inapplecharts  \
# 0              147  141381703                43            263
# ...

# %%
spotify.sample(20)
# Out:
#                                              trackname  \
# 854                                   Me and Your Mama
# 266                                       Shorty Party
# 1                                                 LALA
# 349                                    Kahani Suno 2.0
# 774                                        Silent Hill
# 15                                           Kill Bill
# 98                                  Summertime Sadness
# 0                  Seven (feat. Latto) (Explicit Ver.)
# 716                                            La Zona
# 414                                       Evoque Prata
# 325                                          The Hills
# 652       The Joker And The Queen (feat. Taylor Swift)
# 810                                          TUS L��GR
# 720                            Wake Me Up - Radio Edit
# 715            this is what falling in love feels like
# 781                                            Un Coco
# ...

# %%
col = spotify.columns
col = col.insert(2, "country")
print(col)
spotify["country"] = ""
spotify = spotify[col]
def assign_country(row):
    artists =row["artist(s)name"].lower()
    if "," in artists:
        artists = artists.split(",")[0]
    if artists in artist_country_map:
        row["country"] = artist_country_map[artists]
    return row
spotify=spotify.apply(assign_country, axis=1)
# Out:
# Index(['trackname', 'artist(s)name', 'country', 'artistcount', 'releasedyear',
#        'releasedmonth', 'releasedday', 'inspotifyplaylists', 'inspotifycharts',
#        'streams', 'inappleplaylists', 'inapplecharts', 'indeezerplaylists',
#        'indeezercharts', 'inshazamcharts', 'bpm', 'danceability', 'valence',
#        'energy', 'acousticness', 'instrumentalness', 'liveness',
#        'speechiness'],
#       dtype='object')

# %%
spotify[spotify["trackname"] == "Uminomanimani"]
# Out:
# Empty DataFrame
# Columns: [trackname, artist(s)name, country, artistcount, releasedyear, releasedmonth, releasedday, inspotifyplaylists, inspotifycharts, streams, inappleplaylists, inapplecharts, indeezerplaylists, indeezercharts, inshazamcharts, bpm, danceability, valence, energy, acousticness, instrumentalness, liveness, speechiness]
# Index: []

# %%
spotify.loc[spotify["trackname"] == "������������", "trackname"] = "Uminomanimani"

# %%
spotify[spotify["trackname"] == "Uminomanimani"]
# Out:
#          trackname artist(s)name country  artistcount  releasedyear  \
# 174  Uminomanimani       YOASOBI   Japón            1          2023
#
#      releasedmonth  releasedday  inspotifyplaylists  inspotifycharts  \
# 174              4           12                 356               16
#
#        streams  inappleplaylists  inapplecharts  indeezerplaylists  \
# 174  143573775                35            102                  8
#
#      indeezercharts inshazamcharts  bpm  danceability  valence  energy  \
# 174               1            117  166            57       84      94
#
#      acousticness  instrumentalness  liveness  speechiness
# 174            11                 0        37            9

# %%
spotify["country"].unique()
# Out:
# array(['Estados Unidos', 'Puerto Rico', 'Reino Unido', 'México', 'España',
#        'Corea del Sur', 'Colombia', 'Argentina', 'Canadá', 'Nigeria',
#        'Australia', 'Francia', 'Brasil', 'Irán', 'Indonesia', 'Suecia',
#        'Taiwan', 'India', 'Barbados', 'Japón', ' Armenia', '', 'Irlanda',
#        'Noruega', 'Jamaica', 'Rusia', 'Países Bajos', 'Turquia',
#        'Alemania', 'Pakistan', 'Bélgica', 'Portugal', 'Turquía',
#        'Escocia', 'Cuba', 'Italia', 'Tailandia', 'República Dominicana',
#        'Desconocido', 'Panamá', 'Venezuela'], dtype=object)

# %%
vacio = spotify.loc[spotify['country']=="Desconocido"]

# Imprimir el DataFrame con NaN en la columna "country"
display(vacio)
# Out:
#                       trackname  \
# 569             Salimo de Noche
# 576         The Family Madrigal
# 579                      Freaks
# 580                    Acapulco
# 586                  DANCE CRIP
# ..                          ...
# 920                  BABY OTAKU
# 922                    Miss You
# 923  we fell in love in october
# 928           California Breeze
# 930         Casei Com a Putaria
#
#                                          artist(s)name      country  \
# 569                                  Trueno, Tiago pzk  Desconocido
# 576    Olga Merediz, Stephanie Beatriz, Encanto - Cast  Desconocido
# 579                                         Surf Curse  Desconocido
# 580                                       Jason Derulo  Desconocido
# 586                                             Trueno  Desconocido
# ..                                                 ...          ...
# 920  Fran C, Polima WestCoast, Nickoog Clk, Pablito...  Desconocido
# ...

# %%
vacio.shape
# Out:
# (67, 23)

# %%
vacio["artist(s)name"].tolist()
# Out:
# ['Trueno, Tiago pzk',
#  'Olga Merediz, Stephanie Beatriz, Encanto - Cast',
#  'Surf Curse',
#  'Jason Derulo',
#  'Trueno',
#  'Playboi Carti',
#  'Ti��',
#  'Giveon',
#  'SALES',
#  'Sleepy hallow',
#  'Masked Wolf',
#  'NIKI',
#  'Tate McRae',
#  'Riton, Nightcrawlers, Mufasa & Hypeman, Dopamine',
#  'Tate McRae',
#  'The Rare Occasions',
#  'Intense, AP Dhillon, Gurinder Gill',
#  'Luude, Colin Hay',
#  'GODZZ__-, Zakaria',
#  'Mainstreet, Chefin',
#  'Alvaro Diaz, Rauw Alejandro',
#  'Z�� Fe',
#  'Muni Long',
#  'Vundabar',
#  'V',
#  'Cris Mj',
#  'Eden Mu��',
#  'Treasure',
#  'YEAT',
#  'Danny Ocean',
#  'Lil Tjay',
#  'Matu��, Wiu, ',
#  'Lil Baby',
#  'Ak4:20, Cris Mj, Pailita',
#  'teto',
#  'Polima WestCoast, Pailita',
#  'Benson Boone',
#  'KALUSH',
#  'Shae Gill, Ali Sethi',
#  'Ugly Dray, Tesla Jnr',
#  'Jessi',
#  'Chanel',
#  'Leah Kate',
#  'Sam Ryder',
#  'Kevin Kaarl',
#  'Suki Waterhouse',
#  'BYOR, Imanbek',
#  'Sleepy hallow, 347aidan',
#  'Victor Cibrian',
# ...

# %%
spotify.loc[spotify['trackname'] == 'Alone']
# Out:
#     trackname artist(s)name  country  artistcount  releasedyear  \
# 952     Alone     Burna Boy  Nigeria            1          2022
#
#      releasedmonth  releasedday  inspotifyplaylists  inspotifycharts  \
# 952             11            4                 782                2
#
#       streams  inappleplaylists  inapplecharts  indeezerplaylists  \
# 952  96007391                27             18                 32
#
#      indeezercharts inshazamcharts  bpm  danceability  valence  energy  \
# 952               1              0   90            61       32      67
#
#      acousticness  instrumentalness  liveness  speechiness
# 952            15                 0        11            5

# %%
#spotify.to_csv("final.csv")
